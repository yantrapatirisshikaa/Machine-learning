# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data Gathering

# %%
df = pd.read_csv ("Housing_Prices.csv")
df
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL          65     8450   Pave   NaN      Reg
# 1        2          20       RL          80     9600   Pave   NaN      Reg
# 2        3          60       RL          68    11250   Pave   NaN      IR1
# 3        4          70       RL          60     9550   Pave   NaN      IR1
# 4        5          60       RL          84    14260   Pave   NaN      IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 1455  1456          60       RL          62     7917   Pave   NaN      Reg
# 1456  1457          20       RL          85    13175   Pave   NaN      Reg
# 1457  1458          70       RL          66     9042   Pave   NaN      Reg
# 1458  1459          20       RL          68     9717   Pave   NaN      Reg
# 1459  1460          20       RL          75     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0     NP     NF          NO       0
# 1            Lvl    AllPub  ...        0     NP     NF          NO       0
# 2            Lvl    AllPub  ...        0     NP     NF          NO       0
# 3            Lvl    AllPub  ...        0     NP     NF          NO       0
# 4            Lvl    AllPub  ...        0     NP     NF          NO       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0     NP     NF          NO       0
# 1456         Lvl    AllPub  ...        0     NP  MnPrv          NO       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0     NP     NF          NO       0
# 1459         Lvl    AllPub  ...        0     NP     NF          NO       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
#Data Cleaning

# %%
# Removing the columns as required

# %%
housing_prices = df[['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
        'Utilities','Neighborhood','BldgType','OverallCond', 'YearBuilt','Foundation',
       'BsmtCond', 'BsmtExposure','Heating','HeatingQC', 'CentralAir', 'Electrical','FullBath',
       'BedroomAbvGr', 'KitchenAbvGr','Fireplaces','GarageType','GarageCars','PoolQC',
       'Fence', 'MiscFeature','SaleCondition', 'SalePrice']]

# %%
# Dropping Null values

# %%
housing_prices['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', 'No', 'Fa', 'Po'], dtype=object)

# %%
for i in range(len(housing_prices['BsmtCond'])):
    if housing_prices['BsmtCond'][i] == "No":
        housing_prices['BsmtCond'][i] = housing_prices['BsmtCond'][i].replace("No","No Basement")
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_21248\1232118198.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_prices['BsmtCond'][i] = housing_prices['BsmtCond'][i].replace("No","No Basement")

# %%
housing_prices['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', 'No Basement', 'Fa', 'Po'], dtype=object)

# %%
housing_prices['GarageType'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'NP', 'Basment',
#        '2Types'], dtype=object)

# %%
for i in range(len(housing_prices['GarageType'])):
    if housing_prices['GarageType'][i] == "NP":
        housing_prices['GarageType'][i] = housing_prices['GarageType'][i].replace("NP","NG")
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_21248\1606176930.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_prices['GarageType'][i] = housing_prices['GarageType'][i].replace("NP","NG")

# %%
housing_prices['GarageType'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'NG', 'Basment',
#        '2Types'], dtype=object)

# %%
housing_prices['PoolQC'].unique()
# Out:
# array(['NP', nan, 'Ex', 'Fa', 'Gd'], dtype=object)

# %%
housing_prices['Fence'].unique()
# Out:
# array(['NF', 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
for i in range(len(housing_prices['Fence'])):
    if housing_prices['Fence'][i] == "NF":
        housing_prices['Fence'][i] = housing_prices['Fence'][i].replace("NF","No Fence")
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_21248\1785464482.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_prices['Fence'][i] = housing_prices['Fence'][i].replace("NF","No Fence")

# %%
housing_prices['Fence'].unique()
# Out:
# array(['No Fence', 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
housing_prices['MiscFeature'].unique()
# Out:
# array(['NO', 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
for i in range(len(housing_prices['MiscFeature'])):
    if housing_prices['MiscFeature'][i] == "NO":
        housing_prices['MiscFeature'][i] = housing_prices['GarageType'][i].replace("NO","None")
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_21248\2166168109.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_prices['MiscFeature'][i] = housing_prices['GarageType'][i].replace("NO","None")

# %%
housing_prices.shape
# Out:
# (1460, 28)

# %%
housing_prices.isnull().sum(axis=0)
# Out:
# MSSubClass        0
# MSZoning          0
# LotFrontage      15
# LotArea           0
# Street            0
# Utilities         0
# Neighborhood      0
# BldgType          0
# OverallCond       0
# YearBuilt         0
# Foundation        0
# BsmtCond          0
# BsmtExposure      0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# FullBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# Fireplaces        0
# GarageType        0
# GarageCars        0
# PoolQC           22
# Fence             0
# MiscFeature       0
# SaleCondition     0
# SalePrice         0
# dtype: int64

# %%
housing_prices = housing_prices.dropna(axis=0)
housing_prices = housing_prices.reset_index()

# %%
housing_prices.shape
# Out:
# (1427, 29)

# %%
# New Section

# %%
housing_prices.duplicated().value_counts()
# Out:
# False    1427
# dtype: int64

# %%
type(housing_prices)
# Out:
# pandas.core.frame.DataFrame

# %%
housing_prices.dtypes
# Out:
# index             int64
# MSSubClass        int64
# MSZoning         object
# LotFrontage      object
# LotArea           int64
# Street           object
# Utilities        object
# Neighborhood     object
# BldgType         object
# OverallCond       int64
# YearBuilt         int64
# Foundation       object
# BsmtCond         object
# BsmtExposure     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# FullBath          int64
# BedroomAbvGr      int64
# KitchenAbvGr      int64
# Fireplaces        int64
# GarageType       object
# GarageCars        int64
# PoolQC           object
# Fence            object
# MiscFeature      object
# SaleCondition    object
# SalePrice         int64
# dtype: object

# %%
housing_prices.to_csv("housing_prices_test.csv", index = False)

# %%
housing_prices
# Out:
#       index  MSSubClass MSZoning LotFrontage  LotArea Street Utilities  \
# 0         0          60       RL          65     8450   Pave    AllPub
# 1         1          20       RL          80     9600   Pave    AllPub
# 2         2          60       RL          68    11250   Pave    AllPub
# 3         3          70       RL          60     9550   Pave    AllPub
# 4         4          60       RL          84    14260   Pave    AllPub
# ...     ...         ...      ...         ...      ...    ...       ...
# 1422   1454          20       FV          62     7500   Pave    AllPub
# 1423   1455          60       RL          62     7917   Pave    AllPub
# 1424   1456          20       RL          85    13175   Pave    AllPub
# 1425   1458          20       RL          68     9717   Pave    AllPub
# 1426   1459          20       RL          75     9937   Pave    AllPub
#
#      Neighborhood BldgType  OverallCond  ...  BedroomAbvGr KitchenAbvGr  \
# 0         CollgCr     1Fam            5  ...             3            1
# 1         Veenker     1Fam            8  ...             3            1
# 2         CollgCr     1Fam            5  ...             3            1
# 3         Crawfor     1Fam            5  ...             3            1
# 4         NoRidge     1Fam            5  ...             4            1
# ...           ...      ...          ...  ...           ...          ...
# 1422      Somerst     1Fam            5  ...             2            1
# 1423      Gilbert     1Fam            5  ...             3            1
# 1424       NWAmes     1Fam            6  ...             3            1
# 1425        NAmes     1Fam            6  ...             2            1
# 1426      Edwards     1Fam            6  ...             3            1
#
#      Fireplaces GarageType GarageCars PoolQC     Fence MiscFeature  \
# 0             0     Attchd          2     NP  No Fence      Attchd
# 1             1     Attchd          2     NP  No Fence      Attchd
# 2             1     Attchd          2     NP  No Fence      Attchd
# 3             1     Detchd          3     NP  No Fence      Detchd
# 4             1     Attchd          3     NP  No Fence      Attchd
# ...         ...        ...        ...    ...       ...         ...
# 1422          0     Attchd          2     NP  No Fence      Attchd
# 1423          1     Attchd          2     NP  No Fence      Attchd
# 1424          2     Attchd          2     NP     MnPrv      Attchd
# 1425          0     Attchd          1     NP  No Fence      Attchd
# 1426          0     Attchd          1     NP  No Fence      Attchd
#
#       SaleCondition  SalePrice
# 0            Normal     208500
# 1            Normal     181500
# 2            Normal     223500
# 3           Abnorml     140000
# 4            Normal     250000
# ...             ...        ...
# 1422         Normal     185000
# 1423         Normal     175000
# 1424         Normal     210000
# 1425         Normal     142125
# 1426         Normal     147500
#
# [1427 rows x 29 columns]

# %%
#Visualizing to get more Insight

# %%
sns.pairplot(data = housing_prices)

# %%
corr = housing_prices.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.title("Heat Map of all the Quantitative Values")
# Out:
# Text(0.5, 1.0, 'Heat Map of all the Quantitative Values')

# %%
#There is a very good co-relation between subclass,Lot area, Full bath. Sales prices is highly corelated with years built,Fullbath,Garage cars

# %%
sns.lmplot(x="YearBuilt", y="SalePrice", data=housing_prices);
plt.title("Linear Model Plot related to year built and saleprice")
# Out:
# Text(0.5, 1.0, 'Linear Model Plot related to year built and saleprice')

# %%
#Yearbuilt and sale price are co-related to each other, As the year increases the sale price increases,so for the new houses the salesprice increases.

# %%
sns.regplot(data = housing_prices, x ="KitchenAbvGr", y="FullBath")
plt.title("A plot to determine the relation between Linear feet of kitchen and Fullbath")
# Out:
# Text(0.5, 1.0, 'A plot to determine the relation between Linear feet of kitchen and Fullbath')

# %%
# For kitchens one or two the Fullbath rooms avilibility is not increasing and remains same.

# %%
sns.scatterplot(data = housing_prices, x ="MSSubClass", y="YearBuilt")
plt.title("Relation between type of dwelling and YearBuilt")
# Out:
# Text(0.5, 1.0, 'Relation between type of dwelling and YearBuilt')

# %%
#If MSSubclass less than 100 they are older homes are unfurnished home and if MSSubclass greater than 100 are newly built ones

# %%
sns.histplot(data =  housing_prices, x ="OverallCond", kde="LotFrontage", color="green")
plt.ylabel("Number of Lotfrontage")
plt.xlabel("Number of Overall Condition")
plt.title("Relation between overallcondition and Lotfrontage")
# Out:
# Text(0.5, 1.0, 'Relation between overallcondition and Lotfrontage')

# %%
# If the overall condition is 5, it is medium; the more Linear feet of street connected to property in lotfrontage, the higher.

# %%
sns.violinplot(data = housing_prices, y="YearBuilt")
# Out:
# <AxesSubplot:ylabel='YearBuilt'>

# %%
# The violin plot is considered for housing prices as the housing prices are increased from 1850 to 2025

# %%
sns.boxplot(data = housing_prices, x = "Foundation", y = "Fireplaces")
# Out:
# <AxesSubplot:xlabel='Foundation', ylabel='Fireplaces'>

# %%
#  If the house has only one fireplace, the foundation materials used are all the same.

# %%
plt.figure(figsize=(8,5))
values = housing_prices['BldgType'].value_counts()
labels = housing_prices['BldgType'].unique().tolist()
plt.pie(values,labels=labels,radius=1)
plt.title("Pie Chart of different Types of Buildings")
plt.show()

# %%
# According to the pie chart, the most common construction types are single-family houses (almost 80%) and townhouses with inside units(Twnhs) less than 1%.

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data = housing_prices['GarageType'])
plt.title("Line plot on Garage Types")
# Out:
# Text(0.5, 1.0, 'Line plot on Garage Types')

# %%
#The line plot allows us to see any patterns or trends in the data and make meaningful comparisons between the different garage types. In this particular plot, we can see that the mean sale price for properties with a garage type of "Attached" is significantly higher than the mean sale price for properties with other types of garages.

# %%
sns.barplot(data = housing_prices ['SalePrice'])
# Out:
# <AxesSubplot:>

# %%
# The plot shows the frequency of different sale price ranges, with each bar representing a different price range and the height of the bar indicating the number of properties within that range. The bar plot allows us to see the spread of the data and identify any patterns or trends. For example, we can see from the plot that the majority of properties in the dataset have a sale price between 100,000 and 200,000 dollars, with a smaller number of properties having sale prices above or below this range. Additionally, the bar plot highlights any outliers in the data, such as properties with exceptionally high or low sale prices.

# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=housing prices&'
       'apiKey=7e5b0bb5b2d147a3b66260545d763f2b')

response = requests.get(url)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
jsontxt = response.json()

# %%
response.content
# Out:
# b'{"status":"ok","totalResults":4215,"articles":[{"source":{"id":null,"name":"Lifehacker.com"},"author":"Daniel Oropeza","title":"These Prices Are Expected to Drop This Year","description":"They say that everything that goes up, must come down\xe2\x80\x94but inflation has made that hard to believe last year. While not all the prices that went up in 2022 are expected to come down this year, some will. In 2022, inflation peaked in June at 9.1%, and has gradu\xe2\x80\xa6","url":"https://lifehacker.com/these-prices-are-expected-to-drop-this-year-1849976190","urlToImage":"https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/f222501ca12bc8e9e99b02e4698b2f54.jpg","publishedAt":"2023-01-11T21:30:00Z","content":"They say that everything that goes up, must come downbut inflation has made that hard to believe last year. While not all the prices that went up in 2022 are expected to come down this year, some wil\xe2\x80\xa6 [+3193 chars]"},{"source":{"id":null,"name":"Gizmodo.com"},"author":"Angely Mercado","title":"Climate Gentrification Is Coming to Hurricane-Wrecked Florida","description":"You might assume that home prices would decline in an area recently wrecked by a hurricane, but a new study finds the opposite is true, and post-storm price hikes could be a major driver of what\xe2\x80\x99s known as climate gentrification. Read more...","url":"https://gizmodo.com/climate-gentrification-is-coming-to-hurricane-wrecked-f-1849981170","urlToImage":"https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/d09672efe24c2460d522edaf37345f3a.jpg","publishedAt":"2023-01-13T16:57:00Z","content":"You might assume that home prices would decline in an area recently wrecked by a hurricane, but a new study finds the opposite is true, and post-storm price hikes could be a major driver of whats kno\xe2\x80\xa6 [+3654 chars]"},{"source":{"id":"reuters","name":"Reuters"},"author":null,"title":"Israel posts 5.3% inflation rate in 2022 - Reuters.com","description":"Israel posted an inflation rate of 5.3% in 2022, Israel\'s Central Bureau of Statistics said on Sunday, citing gains of housing, food and transportation and telecommunications prices.","url":"https://www.reuters.com/world/middle-east/israel-posts-53-inflation-rate-2022-2023-01-15/","urlToImage":"https://www.reuters.com/resizer/IgcTny_BVe_hPp2aU27yVXsG1W0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/I6DNCFYJCNPC5OKKNW3N3PJCRQ.jpg","publishedAt":"2023-01-15T16:55:00Z","content":"JERUSALEM, Jan 15 (Reuters) - Israel posted an inflation rate of 5.3% in 2022, Israel\'s Central Bureau of Statistics said on Sunday, citing gains of housing, food and transportation and telecommunica\xe2\x80\xa6 [+652 chars]"},{"source":{"id":"business-insider","name":"Business Insider"},"author":"ztayeb@businessinsider.com (Zahra Tayeb)","title":"The US housing market is stuck in the \'doldrums\' as mortgage rates edge higher, says Freddie Mac","description":"\\"The housing market remains in the doldrums with declining sales, inventory and prices,\\" Sam Khater, chief economist at Freddie Mac, said.","url":"https://markets.businessinsider.com/news/stocks/us-housing-market-mortgage-rates-federal-reserve-freddie-mac-2022-12","urlToImage":"https://i.insider.com/63515d6f50acbb0019ddbcdb?width=1200&format=jpeg","publishedAt":"2022-12-30T12:09:14Z","content":"America\'s housing market is still gloomy as ever as mortgage rates turned higher again, according to Freddie Mac.\xc2\xa0\\r\\n\\"The housing market remains in the doldrums with declining sales, inventory and pri\xe2\x80\xa6 [+1403 chars]"},{"source":{"id":"cnn","name":"CNN"},"author":"Chris Isidore","title":"Canada is banning some foreigners from buying property after home prices surged","description":"Canada in 2023 is closing its doors to foreign investors who want to purchase homes.","url":"https://www.cnn.com/20 ...

# %%
filename="Housing_Prices_Headlines.csv"
MyFILE=open(filename,"w")
WriteThis="Date,Source,Title,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
MyFILE=open(filename, "a")

# %%
import re
for items in jsontxt["articles"]:
    Source=items["source"]["id"]    
    Date=items["publishedAt"]
    NewDate=Date.split("T")
    Date=NewDate[0]
    ## CLEAN the Title
    ##Replace punctuation with space
    # Accept one or more copies of punctuation         
    # plus zero or more copies of a space
    # and replace it with a single space
    Title=items["title"]
    Title=re.sub(r'[,.;@#?!&$\-\']+', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(' +', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(r'\"', ' ', Title, flags=re.IGNORECASE)
    
    # and replace it with a single space
    ## NOTE: Using the "^" on the inside of the [] means
    ## we want to look for any chars NOT a-z or A-Z and replace
    ## them with blank. This removes chars that should not be there.
    Title=re.sub(r'[^a-zA-Z]', " ", Title, flags=re.VERBOSE)
    Title=Title.replace(',', '')
    Title=' '.join(Title.split())
    Title=re.sub("\n|\r", "", Title)
    ##----------------------------------------------------------
    
    Headline=items["description"]
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", str(Headline), flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if len(wd)>3])
    WriteThis=str(Date)+","+str(Source)+","+ str(Title) + "," + str(Headline) + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
housing_prices_api = pd.read_csv(filename, error_bad_lines=False)
print(housing_prices_api.head())
# iterating the columns 
for col in housing_prices_api.columns: 
    print(col) 
    
print(housing_prices_api["Headline"])

## REMOVE any rows with NaN in them
housing_prices_api = housing_prices_api.dropna()
print(housing_prices_api["Headline"])

### Tokenize and Vectorize the Headlines
## Create the list of headlines
HeadlineLIST = []
for next1 in housing_prices_api["Headline"]:
    HeadlineLIST.append(next1)

print("The headline list is")
print(HeadlineLIST)
# Out:
#                                           Date  \
# 0  prices set for drop Nomura predicts Reuters
# 1                                   2023-01-16
# 2                                   2023-01-15
# 3                                   2022-12-31
# 4                                   2023-01-25
#
#                                               Source  \
# 0  British house prices look track fall around ec...
# 1                                            reuters
# 2                                            reuters
# 3                                   business-insider
# 4                                   business-insider
#
#                                                Title  \
# 0                                                NaN
# 1  Asking prices for UK homes rise after mini bud...
# 2  Saudi inflation edges up to in December Reuter...
# 3  The most honest man in real estate thinks the ...
# 4  The worst is over for the US housing market an...
#
#                                             Headline
# 0                                                NaN
# 1  Asking prices British homes rose first time mo...
# 2  Saudi Arabia annual inflation rate ticked Dece...
# 3  Jonathan Miller everyone trusts explain what h...
# 4  House prices likely fall around from their pea...
# Date
# Source
# Title
# Headline
# 0                                                    NaN
# 1      Asking prices British homes rose first time mo...
# 2      Saudi Arabia annual inflation rate ticked Dece...
# 3      Jonathan Miller everyone trusts explain what h...
# 4      House prices likely fall around from their pea...
#                              ...
# 269    price spot iron been major beneficiaries expec...
# 270    Owning home still cornerstone American dream m...
# 271                                                 None
# 272    Chairman Jerome Powell said conference Stockho...
# 273    worries grew about Federal Reserve other centr...
# Name: Headline, Length: 274, dtype: object
# 1      Asking prices British homes rose first time mo...
# 2      Saudi Arabia annual inflation rate ticked Dece...
# 3      Jonathan Miller everyone trusts explain what h...
# 4      House prices likely fall around from their pea...
# 5      Although Florida states that income high price...
#                              ...
# 269    price spot iron been major beneficiaries expec...
# 270    Owning home still cornerstone American dream m...
# 271                                                 None
# 272    Chairman Jerome Powell said conference Stockho...
# 273    worries grew about Federal Reserve other centr...
# Name: Headline, Length: 273, dtype: object
# The headline list is
# ['Asking prices British homes rose first time months housing market showed signs calming after turmoil triggered former prime minister Truss mini budget property website Rightmove href https reuters', 'Saudi Arabia annual inflation rate ticked December from November government data showed Sunday with price rises again driven mainly housing costs', 'Jonathan Miller everyone trusts explain what heck going with home prices Here there', 'House prices likely fall around from their peak there could steeper declines west coast bank warned', 'Although Florida states that income high prices insurance housing healthcare could mean that residents save much they think', 'Mortgage rates could remain high inflation indicators stay prices rebound Fannie said sees mild recession', 'Even millionaires noticing that grocery shopping become really expensive Just listen Cardi', 'Housing largest measure Consumer Price Index making single most influential component inflation', 'Highly paid remote workers drove house prices during pandemic they flocking cities where easier build cheaper homes', 'housing price collapse coalition renters mortgage holders emerge that would doom Conservative electoral baseThe Conservative party good reason think that vote only safe house prices victory could ascribe', 'Mortgage rates have been falling this month remain today housing market conditions ease buyers should find more affordability this year', 'only solution home prices fall Glenn Kelman said struggle millennial homebuyers face during Barron Live podcast episode', 'market historian cofounder blasted bitcoin warned global housing slump underlined dangers bear market rallies', 'mortgage rates fall inflation slows Millennials could revive housing market this year', 'Halifax reports that average house prices fell December pulling annual growth down annual house price growth continued slow December activity softens market gradually returns something closer what were used', 'Rising mortgage rates caused housing market falter leading significant slowdown demand lumber', 'Insider Phil Rosen explains what latest housing lumber data suggest home market', 'Housebuilder also cuts land purchases with forced scrap proposals plots Business live updates Marked slowdown housing market Britain largest housebuilder Barratt Developments introduced hiring freeze', 'homebuilder Horton href https reuters companies target blank beat estimates first quarter profit Tuesday helped higher home prices demand outpaced supply material labor shortages', 'Kenya inflation dipped year year December down from month earlier statistics office said Friday easing second month lower food fuel prices', 'Property crashing everywhere except Singapore Asian city state private residential prices year year according third quarter data from Knight Frank That sharp contrast major cities like Hong Kong Sydney which', 'Some prospective buyers have lamented torrid pace Canada real estate market moved recent years many feel year their luck changes', 'consumer prices unexpectedly fell first time more than years December amid declining prices gasoline other goods suggesting that inflation sustained downward trend', 'Most major Gulf markets ended higher Sunday reflecting Friday rise prices driven prospects that upbeat economic growth outlook from China could signal increased fuel demand world second largest economy', 'Developers mortgage lenders local governments take steps ensure that more people have affordable housing', 'Property market defied gravity years analysts rising mortgage rates will mirror price crashBritain estate agents normally radiate optimism they will watching anxiously noon next Thursday when Bank England expect', 'scarcity problem Some economists politicians want abundance agenda combat surging costs housing childcare college', 'British annual house price growth marked further sharp slowdown December mortgage lender Nationwide said Friday adding that final month also prices record their worst s ...
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\337385678.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   housing_prices_api = pd.read_csv(filename, error_bad_lines=False)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rissh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

# %%
import numpy as np
def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I | re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc


normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(HeadlineLIST)

# %%
temp = pd.DataFrame()

# %%
temp_1 = temp.append(norm_corpus[0].split()).T
for i in range(1,len(norm_corpus)):
    temp_2 = temp.append(norm_corpus[i].split()).T
    temp_1 = pd.concat([temp_1,temp_2])
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_1 = temp.append(norm_corpus[0].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# ...
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T

# %%
temp_1['label'] = 'housing_prices'
temp_1
# Out:
#            0        1         2            3              4             5  \
# 0     asking   prices   british        homes           rose         first
# 0      saudi   arabia    annual    inflation           rate        ticked
# 0   jonathan   miller  everyone       trusts        explain          heck
# 0      house   prices    likely         fall         around          peak
# 0   although  florida    states       income           high        prices
# ..       ...      ...       ...          ...            ...           ...
# 0      price     spot      iron        major  beneficiaries  expectations
# 0     owning     home     still  cornerstone       american         dream
# 0       none      NaN       NaN          NaN            NaN           NaN
# 0   chairman   jerome    powell         said     conference     stockholm
# 0    worries     grew   federal      reserve        central         banks
#
#             6         7           8         9  ...      20        21       22  \
# 0        time    months     housing    market  ...  budget  property  website
# 0    december  november  government      data  ...     NaN       NaN      NaN
# 0       going      home      prices       NaN  ...     NaN       NaN      NaN
# 0       could   steeper    declines      west  ...     NaN       NaN      NaN
# 0   insurance   housing  healthcare     could  ...     NaN       NaN      NaN
# ..        ...       ...         ...       ...  ...     ...       ...      ...
# 0      strong    demand       china     opens  ...     NaN       NaN      NaN
# 0        many     build      wealth   happens  ...     NaN       NaN      NaN
# 0         NaN       NaN         NaN       NaN  ...     NaN       NaN      NaN
# 0   restoring     price   stability  requires  ...     NaN       NaN      NaN
# 0     willing     bring   recession   control  ...     NaN       NaN      NaN
#
#            23    24     25       26   27   28           label
# 0   rightmove  href  https  reuters  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# ..        ...   ...    ...      ...  ...  ...             ...
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
# 0         NaN   NaN    NaN      NaN  NaN  NaN  housing_prices
#
# [273 rows x 30 columns]

# %%
# inflation

# %%
test = pd.read_csv ("Housing_Prices_Headlines.csv")
test.head()
# Out:
#                                           Date  \
# 0  prices set for drop Nomura predicts Reuters
# 1                                   2023-01-16
# 2                                   2023-01-15
# 3                                   2022-12-31
# 4                                   2023-01-25
#
#                                               Source  \
# 0  British house prices look track fall around ec...
# 1                                            reuters
# 2                                            reuters
# 3                                   business-insider
# 4                                   business-insider
#
#                                                Title  \
# 0                                                NaN
# 1  Asking prices for UK homes rise after mini bud...
# 2  Saudi inflation edges up to in December Reuter...
# 3  The most honest man in real estate thinks the ...
# 4  The worst is over for the US housing market an...
#
#                                             Headline
# 0                                                NaN
# 1  Asking prices British homes rose first time mo...
# 2  Saudi Arabia annual inflation rate ticked Dece...
# 3  Jonathan Miller everyone trusts explain what h...
# 4  House prices likely fall around from their pea...

# %%
test.dtypes
# Out:
# Date        object
# Source      object
# Title       object
# Headline    object
# dtype: object

# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q= housing market&'
       'apiKey=7e5b0bb5b2d147a3b66260545d763f2b')

response = requests.get(url)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
jsontxt = response.json()

# %%
response.content
# Out:
# b'{"status":"ok","totalResults":7049,"articles":[{"source":{"id":"business-insider","name":"Business Insider"},"author":"alloyd@insider.com (Alcynna Lloyd)","title":"Homebuilders may finally be turning a corner as inflation stabilizes and lower mortgage rates bring buyers back into the market","description":"As mortgage rates fall and inflation slows, Millennials could revive the US housing market this year.","url":"https://www.businessinsider.com/2023-could-be-the-year-that-the-us-housing-market-gets-back-on-track-2023-1","urlToImage":"https://i.insider.com/63c83913eee94d001a78d3d2?width=1200&format=jpeg","publishedAt":"2023-01-18T18:35:55Z","content":"The home buying frenzy that took place throughout much of the pandemic drove the nation\'s home prices to historic highs, further escalating the country\'s ongoing housing shortage and affordability cr\xe2\x80\xa6 [+3426 chars]"},{"source":{"id":"business-insider","name":"Business Insider"},"author":"tmohamed@businessinsider.com (Theron Mohamed)","title":"Legendary investor Jeremy Grantham flagged a \'superbubble\' in asset prices and predicted a historic market crash. Here are his 8 best quotes of 2022.","description":"The market historian and GMO cofounder blasted bitcoin, warned of a global housing slump and underlined the dangers of bear-market rallies.","url":"https://markets.businessinsider.com/news/stocks/jeremy-grantham-superbubble-stock-housing-market-crash-bitcoin-best-quotes-2023-1","urlToImage":"https://i.insider.com/63ad96a73e42ed001855ccd4?width=1200&format=jpeg","publishedAt":"2023-01-01T11:45:00Z","content":"Legendary investor Jeremy Grantham rattled Wall Street last year by sounding the alarm on a \\"superbubble\\" in asset prices, and predicting it would end with an epic market crash.\\r\\nThe market historian\xe2\x80\xa6 [+2421 chars]"},{"source":{"id":null,"name":"Lifehacker.com"},"author":"Daniel Oropeza","title":"These Prices Are Expected to Drop This Year","description":"They say that everything that goes up, must come down\xe2\x80\x94but inflation has made that hard to believe last year. While not all the prices that went up in 2022 are expected to come down this year, some will. In 2022, inflation peaked in June at 9.1%, and has gradu\xe2\x80\xa6","url":"https://lifehacker.com/these-prices-are-expected-to-drop-this-year-1849976190","urlToImage":"https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/f222501ca12bc8e9e99b02e4698b2f54.jpg","publishedAt":"2023-01-11T21:30:00Z","content":"They say that everything that goes up, must come downbut inflation has made that hard to believe last year. While not all the prices that went up in 2022 are expected to come down this year, some wil\xe2\x80\xa6 [+3193 chars]"},{"source":{"id":null,"name":"The Guardian"},"author":"Kalyeena Makortoff","title":"Barratt brings in hiring freeze as UK housing market slows down","description":"Housebuilder also cuts land purchases, with it forced to scrap proposals for 3,293 plots<ul><li>Business live updates: \xe2\x80\x98Marked slowdown\xe2\x80\x99 in UK housing market</li></ul>Britain\xe2\x80\x99s largest housebuilder, Barratt Developments, has introduced a hiring freeze and is \xe2\x80\xa6","url":"https://www.theguardian.com/business/2023/jan/11/barratt-hiring-freeze-uk-housing-market-slows-down","urlToImage":"https://i.guim.co.uk/img/media/dcfd549923b8c605d1f42e740df9e0457a1cd3ea/538_5_1986_1192/master/1986.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=130a059335ad67d71cb41ca3eec07967","publishedAt":"2023-01-11T08:45:35Z","content":"Britains largest housebuilder, Barratt Developments, has introduced a hiring freeze and is significantly cutting back on buying land as it steels itself for a further slump in the UK housing market.\\r\xe2\x80\xa6 [+2873 chars]"},{"source":{"id":"business- ...

# %%
filename="housing_market_headlines.csv"
MyFILE=open(filename,"w")
WriteThis="Date,Source,Title,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
MyFILE=open(filename, "a")

# %%
import re
for items in jsontxt["articles"]:
    Source=items["source"]["id"]    
    Date=items["publishedAt"]
    NewDate=Date.split("T")
    Date=NewDate[0]
    ## CLEAN the Title
    ##Replace punctuation with space
    # Accept one or more copies of punctuation         
    # plus zero or more copies of a space
    # and replace it with a single space
    Title=items["title"]
    Title=re.sub(r'[,.;@#?!&$\-\']+', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(' +', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(r'\"', ' ', Title, flags=re.IGNORECASE)
    
    # and replace it with a single space
    ## NOTE: Using the "^" on the inside of the [] means
    ## we want to look for any chars NOT a-z or A-Z and replace
    ## them with blank. This removes chars that should not be there.
    Title=re.sub(r'[^a-zA-Z]', " ", Title, flags=re.VERBOSE)
    Title=Title.replace(',', '')
    Title=' '.join(Title.split())
    Title=re.sub("\n|\r", "", Title)
    ##----------------------------------------------------------
    
    Headline=items["description"]
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", str(Headline), flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if len(wd)>3])
    WriteThis=str(Date)+","+str(Source)+","+ str(Title) + "," + str(Headline) + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
housing_market_api = pd.read_csv(filename, error_bad_lines=False)
print(housing_market_api.head())
# iterating the columns 
for col in housing_market_api.columns: 
    print(col) 
    
print(housing_market_api["Headline"])

## REMOVE any rows with NaN in them
housing_market_api = housing_market_api.dropna()
print(housing_market_api["Headline"])

### Tokenize and Vectorize the Headlines
## Create the list of headlines
HeadlineLIST = []
for next1 in housing_market_api["Headline"]:
    HeadlineLIST.append(next1)

print("The headline list is")
print(HeadlineLIST)
# Out:
#          Date            Source  \
# 0  2023-01-18  business-insider
# 1  2023-01-01  business-insider
# 2  2023-01-11              None
# 3  2023-01-11              None
# 4  2023-01-30  business-insider
#
#                                                Title  \
# 0  Homebuilders may finally be turning a corner a...
# 1  Legendary investor Jeremy Grantham flagged a s...
# 2        These Prices Are Expected to Drop This Year
# 3  Barratt brings in hiring freeze as UK housing ...
# 4  Here s why the housing market could see more a...
#
#                                             Headline
# 0  mortgage rates fall inflation slows Millennial...
# 1  market historian cofounder blasted bitcoin war...
# 2  They that everything that goes must come down ...
# 3  Housebuilder also cuts land purchases with for...
# 4  Insider Phil Rosen explains what latest housin...
# Date
# Source
# Title
# Headline
# 0      mortgage rates fall inflation slows Millennial...
# 1      market historian cofounder blasted bitcoin war...
# 2      They that everything that goes must come down ...
# 3      Housebuilder also cuts land purchases with for...
# 4      Insider Phil Rosen explains what latest housin...
#                              ...
# 152    cool live downtown Downtown shut down ghost to...
# 153    should have been down those cuts cuts reason t...
# 154    Dallas Federal Reserve Bank President Lorie Lo...
# 155    Christian Lawrence advocates modular home cons...
# 156    Britain services sector ended lacklustre fashi...
# Name: Headline, Length: 157, dtype: object
# 0      mortgage rates fall inflation slows Millennial...
# 1      market historian cofounder blasted bitcoin war...
# 2      They that everything that goes must come down ...
# 3      Housebuilder also cuts land purchases with for...
# 4      Insider Phil Rosen explains what latest housin...
#                              ...
# 152    cool live downtown Downtown shut down ghost to...
# 153    should have been down those cuts cuts reason t...
# 154    Dallas Federal Reserve Bank President Lorie Lo...
# 155    Christian Lawrence advocates modular home cons...
# 156    Britain services sector ended lacklustre fashi...
# Name: Headline, Length: 157, dtype: object
# The headline list is
# ['mortgage rates fall inflation slows Millennials could revive housing market this year', 'market historian cofounder blasted bitcoin warned global housing slump underlined dangers bear market rallies', 'They that everything that goes must come down inflation made that hard believe last year While prices that went expected come down this year some will inflation peaked June gradu', 'Housebuilder also cuts land purchases with forced scrap proposals plots Business live updates Marked slowdown housing market Britain largest housebuilder Barratt Developments introduced hiring freeze', 'Insider Phil Rosen explains what latest housing lumber data suggest home market', 'bank announced will significantly shifting focus taking step back from housing market', 'modest drop mortgage rates over past month helped home builder confidence improve January after consecutive months falling according survey released Wednesday', 'Contracts previously owned homes increased first time seven months December mortgage rates declined another hopeful sign that embattled housing market starting stabilize', 'India Housing Development Finance Corp href https reuters companies HDFC target blank HDFC HDFC will return bond market after months three merchant bankers said Friday', 'Britain second largest housebuilder Persimmon href https reuters companies target blank warned weak conditions housing market Thursday sharp rise mortgage rates broader economic uncertainty', 'existing home sales plunged year December declining mortgage rates raised cautious hope that embattled housing market could close finding floor', 'Mortgage applications from people looking purchase homes fell lowest level years offering relief cooling housing market', 'Rising mortgage rates caused housing market falter leading significant slowdown demand lumber', 'Mortgage rates have been falling this month remain today housing market conditions ease buyers should find more affordability this year', 'housing market remains doldrums with declining sales inventory prices Khater chief economist Freddie said', 'might assume that home prices would decline area recently wrecked hurricane study finds opposite true post storm price hikes could major driver what known climate gentrification Read more', 'Real estate broker Compass href https reuters companies COMP target blank COMP said Thursday would more jobs deal with downturn housing market target becoming free cash flow positive', 'Investor confidence could severely dented housing markets rolling over economy entering recession corporate profits starting fall', 'bursting global housing bubble likely have more painful economic knock effect than decline equities Grantham said', 'Jonathan Miller everyone trusts explain what heck going with home prices Here there', 'Housing largest measure Consumer Price Index making single most influential component inflation', 'Asking prices British homes rose first time months housing market showed signs calming after turmoil triggered former prime minister Truss mini budget property website Rightmove href https reuters', 'Confidence among single family homebuilders improved first time more than year January potentially signaling housing slump have reached point even construction firms sentiment remains decidedly bearish', 'India Housing Development Finance Corp href https reuters companies HDFC target blank HDFC plans raise least billion rupees million through sale bonds maturing years three merchant bankers said', 'first licensed marijuana store York opened Thursday more than year after state legalized drug during delays setting legal market benefit people previously arrested marijuana crimes', 'Halifax reports that average house prices fell December pulling annual growth down annual house price growth continued slow December activity softens market gradually returns something closer what were used', 'California latest string states cities save renters money repeated application fees legal attorneys laws proving dif ...
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\2924245829.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   housing_market_api = pd.read_csv(filename, error_bad_lines=False)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rissh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

# %%
import numpy as np
def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I | re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc


normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(HeadlineLIST)

# %%
norm_corpus
# Out:
# array(['mortgage rates fall inflation slows millennials could revive housing market year',
#        'market historian cofounder blasted bitcoin warned global housing slump underlined dangers bear market rallies',
#        'everything goes must come inflation made hard believe last year prices went expected come year inflation peaked june gradu',
#        'housebuilder also cuts land purchases forced scrap proposals plots business live updates marked slowdown housing market britain largest housebuilder barratt developments introduced hiring freeze',
#        'insider phil rosen explains latest housing lumber data suggest home market',
#        'bank announced significantly shifting focus taking step back housing market',
#        'modest drop mortgage rates past month helped home builder confidence improve january consecutive months falling according survey released wednesday',
#        'contracts previously owned homes increased first time seven months december mortgage rates declined another hopeful sign embattled housing market starting stabilize',
#        'india housing development finance corp href https reuters companies hdfc target blank hdfc hdfc return bond market months three merchant bankers said friday',
#        'britain second largest housebuilder persimmon href https reuters companies target blank warned weak conditions housing market thursday sharp rise mortgage rates broader economic uncertainty',
#        'existing home sales plunged year december declining mortgage rates raised cautious hope embattled housing market could close finding floor',
#        'mortgage applications people looking purchase homes fell lowest level years offering relief cooling housing market',
#        'rising mortgage rates caused housing market falter leading significant slowdown demand lumber',
#        'mortgage rates falling month remain today housing market conditions ease buyers find affordability year',
#        'housing market remains doldrums declining sales inventory prices khater chief economist freddie said',
#        'might assume home prices would decline area recently wrecked hurricane study finds opposite true post storm price hikes could major driver known climate gentrification read',
#        'real estate broker compass href https reuters companies comp target blank comp said thursday would jobs deal downturn housing market target becoming free cash flow positive',
#        'investor confidence could severely dented housing markets rolling economy entering recession corporate profits starting fall',
#        'bursting global housing bubble likely painful economic knock effect decline equities grantham said',
#        'jonathan miller everyone trusts explain heck going home prices',
#        'housing largest measure consumer price index making single influential component inflation',
#        'asking prices british homes rose first time months housing market showed signs calming turmoil triggered former prime minister truss mini budget property website rightmove href https reuters',
#        'confidence among single family homebuilders improved first time year january potentially signaling housing slump reached point even construction firms sentiment remains decidedly bearish',
#        'india housing development finance corp href https reuters companies hdfc target blank hdfc plans raise least billion rupees million sale bonds maturing years three merchant bankers said',
#        'first licensed marijuana store york opened thursday year state legalized drug delays setting legal market benefit people previously arrested marijuana crimes',
#        'halifax reports average house prices fell december pulling annual growth annual house price growth continued slow december activity softens market gradually returns something closer used',
#        'california latest string states cities save renters money repeated application fees legal attorneys laws proving difficult enforce',
#        'developers mortgage lenders local governments take steps ensure people affordable housing',
#        'house prices likely fall around peak could steeper declines west coast bank warned',
#        'china boost financing good quality property developers roll billion yuan billion support plan rental housing loans official xinhua news agency said friday',
#        'construction spending unexpectedly rebounded november lifted gains nonresidential structures single family homebuilding continued hammered higher mortgage rates',
#        'housing companies blocked development work unless agree cladding removal repairs unsafe multi storey buildings bill totalling billion pounds billion british government said monday',
#        'people paying month rent explore options could help housing coststhe cost renting home soared prompting tenants seek cheaper options could save thousands pounds year cost',
#        'mortgage rates could remain high inflation indicators stay prices rebound fannie said sees mild recession',
#        'prospective buyers lamented torrid pace canada real estate market moved recent years many feel year luck changes',
#        'shares chinese property developers climbed friday lifted state support measures bolster highly indebted sector china prepares reopen pandemic economy',
#        'british house prices look track fall around economists japanese bank nomura said thursday severe drop forecasters projected',
#        'federal reserve continues inflation fighting tightrope market moves suggest investors feeling ease central bank actions necessarily good thing',
#        'bofa issued double upgrade zillow rating underperform bumped price objective share',
#        'number americans filing claims unemployment benefits unexpectedly fell last week suggesting labor market remains tight despite higher interest rates',
#        'third week mortgage interest rates fell triggering increase mortgage applications',
#        'highly paid remote workers drove house prices pandemic flocking cities easier build cheaper homes',
#        'china central bank banking insurance regulator established dynamic adjustment mechanism mortgage rates first time home buyers central bank said thursday support property sector',
#        'china property sector fell year earlier value added data national bureau statistics showed wednesday heaping pressure policymakers revive sluggish sector',
#        'country real wealth lies equality environment happiness',
#        'british house prices registered widespread falls years last month buyer demand sales activity weakened sharply expected face higher borrowing costs risk recession survey showed thursday',
#        'british annual house price growth marked sharp slowdown december mortgage lender nationwide said friday adding final month also prices record worst since monthly basis',
#        'investors foresee federal open market committee downshifting rate hikes february march',
#        'economy maintained strong pace growth december unemployment rate falling higher borrowing costs federal reserve fights inflation could labor market momentum slowing significantly year',
#        'number americans filing claims unemployment benefits dropped three month last week layoffs fell december pointing tight labor market could require federal reserve keep hiking interest rates',
#        'foreigners banned buying homes canada canada housing foreign buyers know news federal foreign homebuyers takes effect watch news videos online global news canada',
#        'solution home prices fall glenn kelman said struggle millennial homebuyers face barron live podcast episode',
#        'owning home still cornerstone american dream many build wealth happens pandemic economic headwinds make feel reach',
#        'rents soared across country certain codes reached heights average rent bedroom apartment',
#        'ultra rates desire room lockdown drove house prices heights many moved sufferingin summer british society emerged months covid lockdown housing market reopened',
#        'supreme court monday declined hear multi billion dollar case pursued shareholders fannie freddie arising federal government takeover mortgage finance firms financial crisis',
#        'property crashing everywhere except singapore asian city state private residential prices year year according third quarter data knight frank sharp contrast major cities like hong kong sydney',
#        'mortgage rates fall inflation slows millennials could revive housing market year',
#        'market historian cofounder blasted bitcoin warned global housing slump underlined dangers bear market rallies',
#        'everything goes must come inflation made hard believe last year prices went expected come year inflation peaked june gradu',
#        'housebuilder also cuts land purchases forced scrap proposals plots business live updates marked slowdown housing market britain largest housebuilder barratt developments introduced hiring freeze',
#        'insider phil rosen explains latest housing lumber data suggest home market',
#        'bank announced significantly shifting focus taking step back housing market',
#        'modest drop mortgage rates past month helped home builder confidence improve january consecutive months falling according survey released wednesday',
#        'contracts previously owned homes increased first time seven months december mortgage rates declined another hopeful sign embattled housing market starting stabilize',
#        'india housing development finance corp href https reuters companies hdfc target blank hdfc hdfc return bond market months three merchant bankers said friday',
#        'britain second largest housebuilder persimmon href https reuters companies target blank warned weak conditions housing market thursday sharp rise mortgage rates broader economic uncertainty',
#        'existing home sales plunged year december declining mortgage rates raised cautious hope embattled housing market could close finding floor',
#        'mortgage applications people looking purchase homes fell lowest level years offering relief cooling housing market',
#        'rising mortgage rates caused housing market falter leading significant slowdown demand lumber',
#        'mortgage rates falling month remain today housing market conditions ease buyers find affordability year',
#        'housing market remains doldrums declining sales inventory prices khater chief economist freddie said',
#        'might assume home prices would decline area recently wrecked hurricane study finds opposite true post storm price hikes could major driver known climate gentrification read',
#        'real estate broker compass href https reuters companies comp target blank comp said thursday would jobs deal downturn housing market target becoming free cash flow positive',
#        'investor confidence could severely dented housing markets rolling economy entering recession corporate profits starting fall',
#        'bursting global housing bubble likely painful economic knock effect decline equities grantham said',
#        'jonathan miller everyone trusts explain heck going home prices',
#        'housing largest measure consumer price index making single influential component inflation',
#        'asking prices british homes rose first time months housing market showed signs calming turmoil triggered former prime minister truss mini budget property website rightmove href https reuters',
#        'confidence among single family homebuilders improved first time year january potentially signaling housing slump reached point even construction firms sentiment remains decidedly bearish',
#        'india housing development finance corp href https reuters companies hdfc target blank hdfc plans raise least billion rupees million sale bonds maturing years three merchant bankers said',
#        'first licensed marijuana store york opened thursday year state legalized drug delays setting legal market benefit people previously arrested marijuana crimes',
#        'halifax reports average house prices fell december pulling annual growth annual house price growth continued slow december activity softens market gradually returns something closer used',
#        'california latest string states cities save renters money repeated application fees legal attorneys laws proving difficult enforce',
#        'developers mortgage lenders local governments take steps ensure people affordable housing',
#        'house prices likely fall around peak could steeper declines west coast bank warned',
#        'china boost financing good quality property developers roll billion yuan billion support plan rental housing loans official xinhua news agency said friday',
#        'construction spending unexpectedly rebounded november lifted gains nonresidential structures single family homebuilding continued hammered higher mortgage rates',
#        'housing companies blocked development work unless agree cladding removal repairs unsafe multi storey buildings bill totalling billion pounds billion british government said monday',
#        'people paying month rent explore options could help housing coststhe cost renting home soared prompting tenants seek cheaper options could save thousands pounds year cost',
#        'mortgage rates could remain high inflation indicators stay prices rebound fannie said sees mild recession',
#        'prospective buyers lamented torrid pace canada real estate market moved recent years many feel year luck changes',
#        'shares chinese property developers climbed friday lifted state support measures bolster highly indebted sector china prepares reopen pandemic economy',
#        'british house prices look track fall around economists japanese bank nomura said thursday severe drop forecasters projected',
#        'federal reserve continues inflation fighting tightrope market moves suggest investors feeling ease central bank actions necessarily good thing',
#        'bofa issued double upgrade zillow rating underperform bumped price objective share',
#        'number americans filing claims unemployment benefits unexpectedly fell last week suggesting labor market remains tight despite higher interest rates',
#        'third week mortgage interest rates fell triggering increase mortgage applications',
#        'highly paid remote workers drove house prices pandemic flocking cities easier build cheaper homes',
#        'china central bank banking insurance regulator established dynamic adjustment mechanism mortgage rates first time home buyers central bank said thursday support property sector',
#        'china property sector fell year earlier value added data national bureau statistics showed wednesday heaping pressure policymakers revive sluggish sector',
#        'country real wealth lies equality environment happiness',
#        'british house prices registered widespread falls years last month buyer demand sales activity weakened sharply expected face higher borrowing costs risk recession survey showed thursday',
#        'british annual house price growth marked sharp slowdown december mortgage lender nationwide said friday adding final month also prices record worst since monthly basis',
#        'investors foresee federal open market committee downshifting rate hikes february march',
#        'economy maintained strong pace growth december unemployment rate falling higher borrowing costs federal reserve fights inflation could labor market momentum slowing significantly year',
#        'number americans filing claims unemployment benefits dropped three month last week layoffs fell december pointing tight labor market could require federal reserve keep hiking interest rates',
#        'foreigners banned buying homes canada canada housing foreign buyers know news federal foreign homebuyers takes effect watch news videos online global news canada',
#        'solution home prices fall glenn kelman said struggle millennial homebuyers face barron live podcast episode',
#        'owning home still cornerstone american dream many build wealth happens pandemic economic headwinds make feel reach',
#        'rents soared across country certain codes reached heights average rent bedroom apartment',
#        'ultra rates desire room lockdown drove house prices heights many moved sufferingin summer british society emerged months covid lockdown housing market reopened',
#        'supreme court monday declined hear multi billion dollar case pursued shareholders fannie freddie arising federal government takeover mortgage finance firms financial crisis',
#        'property crashing everywhere except singapore asian city state private residential prices year year according third quarter data knight frank sharp contrast major cities like hong kong sydney',
#        'none',
#        'bofa anticipating drop year mortgage rate year move favorable homebuilding stocks',
#        'dollar staring fourth straight session losses euro monday hawkish comments european interest rates contrasted market pricing less aggressive federal reserve',
#        'demand homes gone throughout country particularly certain places seattle tampa florida',
#        'multiple important refinance rates dropped today interest rate hikes affected refinance market',
#        'multiple benchmark refinance rates declined today interest rate hikes affected refinance market',
#        'history show everyone side usually wrong wharton professor jeremy siegel said',
#        'housing price collapse coalition renters mortgage holders emerge would doom conservative electoral basethe conservative party good reason think vote safe house prices victory could ascribe',
#        'least million people plan real estate markets shown significant resilience home prices decline nationwide',
#        'hopes glengarry affordable woodland homes scheme could provide answers scotland rural housing crisis exciting said colin grant fifth generation farmer glengarry near fort william grant seen community dwindle decades',
#        'protections impact million households come time demand rental units near time high',
#        'none',
#        'several benchmark refinance rates ticked downward today interest rate hikes affected refinance market',
#        'refinance rates mixed rate increased interest rate hikes affected refinance market',
#        'refinance rates mixed rate ticked interest rate hikes affected refinance market',
#        'multiple benchmark refinance rates fell week interest rate hikes affected refinance market',
#        'posted worst loss since market great recession according oppenheimer',
#        'single home sold november according real estate data census bureau',
#        'blaming housing crisis hedge funds private equity easy dead wrong',
#        'property market defied gravity years analysts rising mortgage rates mirror price crashbritain estate agents normally radiate optimism watching anxiously noon next thursday bank england expect',
#        'multiple benchmark refinance rates ticked last week market refi good time assess options',
#        'several refinance rates sunk today market refi good time assess options',
#        'several benchmark refinance rates plummeted week interest rate hikes last year affected refinance market',
#        'figure comes property values drop december decline novemberthe average house price fell fourth month december according halifax property values decreased december',
#        'economy likely maintained solid pace wage growth december rising borrowing costs federal reserve fights inflation could slow labor market momentum significantly year',
#        'said inflation fall quickly would likely mean would begin cutting rates earlier currently anticipate',
#        'average interest rate popular home loan dropped lowest level since september evidence inflation past peak sent treasury yields lower data mortgage bankers association showed wednesday',
#        'export oriented ftse edged higher monday banks life insurance companies among gainers investors looked ahead week lined domestic economic data including inflation',
#        'major gulf markets ended higher sunday reflecting friday rise prices driven prospects upbeat economic growth outlook china could signal increased fuel demand world second largest economy',
#        'mortgage rates remain today rates continue fall homebuyers likely start enter market',
#        'britain construction sector stagnated last year home building particularly hard face rising borrowing costs survey showed thursday',
#        'prologis execs said headlines economic gloom disconnected industrial warehouse business time around',
#        'stock market live news updates stocks lower final trading yahoo canada finance nasdaq back brink worst december ever angst dims bloomberg stocks fall treasury yields rise upon final',
#        'measure enacted tackle pressing issue housing affordability country',
#        'china deeply troubled property sector home sales fall second straight year pace declines ease thanks state support measures lifting government strict anti covid policies',
#        'mortgage rates relatively today compared recent peaks many would homebuyers enter market',
#        'amidst climate energy crisis heat pumps emerged housing heating market technology replace lowering energy bills compression systems require refrigerants work refrigerants',
#        'universities using massive endowments boosted hefty tuition dollars invest commercial real estate property values fall',
#        'cool live downtown downtown shut ghost town still bounced back office buildings forth katsaros said',
#        'cuts cuts reason burry tweeted',
#        'dallas federal reserve bank president lorie logan wednesday laid case slowing pace central bank interest rate hikes better calibrate monetary policy uncertain economic outlook signaled rates could ultimately',
#        'christian lawrence advocates modular home construction says cheaper quicker less wasteful traditional methods',
#        'britain services sector ended lacklustre fashion orders falling hiring frozen december according survey thursday highlighted likelihood britain already recession'],
#       dtype='<U215')

# %%
temp = pd.DataFrame()

# %%
temp_3 = temp.append(norm_corpus[0].split()).T
for i in range(1,len(norm_corpus)):
    temp_4 = temp.append(norm_corpus[i].split()).T
    temp_3 = pd.concat([temp_3,temp_4])
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_3 = temp.append(norm_corpus[0].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_28532\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T

# %%
temp_3['label'] = 'housing_market'
temp_3
# Out:
#                0          1          2          3           4             5  \
# 0       mortgage      rates       fall  inflation       slows   millennials
# 0         market  historian  cofounder    blasted     bitcoin        warned
# 0     everything       goes       must       come   inflation          made
# 0   housebuilder       also       cuts       land   purchases        forced
# 0        insider       phil      rosen   explains      latest       housing
# ..           ...        ...        ...        ...         ...           ...
# 0           cool       live   downtown   downtown        shut         ghost
# 0           cuts       cuts     reason      burry     tweeted           NaN
# 0         dallas    federal    reserve       bank   president         lorie
# 0      christian   lawrence  advocates    modular        home  construction
# 0        britain   services     sector      ended  lacklustre       fashion
#
#          6          7        8           9  ...            20          21  \
# 0    could     revive  housing      market  ...           NaN         NaN
# 0   global    housing    slump  underlined  ...           NaN         NaN
# 0     hard    believe     last        year  ...           NaN         NaN
# 0    scrap  proposals    plots    business  ...  developments  introduced
# 0   lumber       data  suggest        home  ...           NaN         NaN
# ..     ...        ...      ...         ...  ...           ...         ...
# 0     town      still  bounced        back  ...           NaN         NaN
# 0      NaN        NaN      NaN         NaN  ...           NaN         NaN
# 0    logan  wednesday     laid        case  ...        policy   uncertain
# 0     says    cheaper  quicker        less  ...           NaN         NaN
# 0   orders    falling   hiring      frozen  ...           NaN         NaN
#
#           22       23        24     25     26          27   28           label
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
# 0     hiring   freeze       NaN    NaN    NaN         NaN  NaN  housing_market
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
# ..       ...      ...       ...    ...    ...         ...  ...             ...
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
# 0   economic  outlook  signaled  rates  could  ultimately  NaN  housing_market
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
# 0        NaN      NaN       NaN    NaN    NaN         NaN  NaN  housing_market
#
# [157 rows x 30 columns]

# %%
transactions = pd.concat([temp_1,temp_3])

# %%
transactions
# Out:
#             0         1          2          3           4             5  \
# 0      asking    prices    british      homes        rose         first
# 0       saudi    arabia     annual  inflation        rate        ticked
# 0    jonathan    miller   everyone     trusts     explain          heck
# 0       house    prices     likely       fall      around          peak
# 0    although   florida     states     income        high        prices
# ..        ...       ...        ...        ...         ...           ...
# 0        cool      live   downtown   downtown        shut         ghost
# 0        cuts      cuts     reason      burry     tweeted           NaN
# 0      dallas   federal    reserve       bank   president         lorie
# 0   christian  lawrence  advocates    modular        home  construction
# 0     britain  services     sector      ended  lacklustre       fashion
#
#             6          7           8       9  ...      20         21  \
# 0        time     months     housing  market  ...  budget   property
# 0    december   november  government    data  ...     NaN        NaN
# 0       going       home      prices     NaN  ...     NaN        NaN
# 0       could    steeper    declines    west  ...     NaN        NaN
# 0   insurance    housing  healthcare   could  ...     NaN        NaN
# ..        ...        ...         ...     ...  ...     ...        ...
# 0        town      still     bounced    back  ...     NaN        NaN
# 0         NaN        NaN         NaN     NaN  ...     NaN        NaN
# 0       logan  wednesday        laid    case  ...  policy  uncertain
# 0        says    cheaper     quicker    less  ...     NaN        NaN
# 0      orders    falling      hiring  frozen  ...     NaN        NaN
#
#           22         23        24     25       26          27   28  \
# 0    website  rightmove      href  https  reuters         NaN  NaN
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
# ..       ...        ...       ...    ...      ...         ...  ...
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
# 0   economic    outlook  signaled  rates    could  ultimately  NaN
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
# 0        NaN        NaN       NaN    NaN      NaN         NaN  NaN
#
#              label
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# ..             ...
# 0   housing_market
# 0   housing_market
# 0   housing_market
# 0   housing_market
# 0   housing_market
#
# [430 rows x 30 columns]

# %%
transactions = transactions.iloc[: , :-1]

# %%
transactions.to_csv("transactions_data.csv", index = False, header = False)

# %%
test = pd.read_csv ("transactions_data.csv")
test.head()
# Out:
#      asking   prices   british      homes     rose      first        time  \
# 0     saudi   arabia    annual  inflation     rate     ticked    december
# 1  jonathan   miller  everyone     trusts  explain       heck       going
# 2     house   prices    likely       fall   around       peak       could
# 3  although  florida    states     income     high     prices   insurance
# 4  mortgage    rates     could     remain     high  inflation  indicators
#
#      months     housing   market  ... mini budget property website rightmove  \
# 0  november  government     data  ...  NaN    NaN      NaN     NaN       NaN
# 1      home      prices      NaN  ...  NaN    NaN      NaN     NaN       NaN
# 2   steeper    declines     west  ...  NaN    NaN      NaN     NaN       NaN
# 3   housing  healthcare    could  ...  NaN    NaN      NaN     NaN       NaN
# 4      stay      prices  rebound  ...  NaN    NaN      NaN     NaN       NaN
#
#   href https reuters Unnamed: 27 Unnamed: 28
# 0  NaN   NaN     NaN         NaN         NaN
# 1  NaN   NaN     NaN         NaN         NaN
# 2  NaN   NaN     NaN         NaN         NaN
# 3  NaN   NaN     NaN         NaN         NaN
# 4  NaN   NaN     NaN         NaN         NaN
#
# [5 rows x 29 columns]
