# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data Gathering

# %%
df = pd.read_csv ("Housing_Prices.csv")
df
# Out:
#       MSSubClass MSZoning LotFrontage  LotArea Street Utilities Neighborhood  \
# 0             60       RL          65     8450   Pave    AllPub      CollgCr
# 1             20       RL          80     9600   Pave    AllPub      Veenker
# 2             60       RL          68    11250   Pave    AllPub      CollgCr
# 3             70       RL          60     9550   Pave    AllPub      Crawfor
# 4             60       RL          84    14260   Pave    AllPub      NoRidge
# ...          ...      ...         ...      ...    ...       ...          ...
# 1455          60       RL          62     7917   Pave    AllPub      Gilbert
# 1456          20       RL          85    13175   Pave    AllPub       NWAmes
# 1457          70       RL          66     9042   Pave    AllPub      Crawfor
# 1458          20       RL          68     9717   Pave    AllPub        NAmes
# 1459          20       RL          75     9937   Pave    AllPub      Edwards
#
#      BldgType  OverallCond  YearBuilt  ... BedroomAbvGr KitchenAbvGr  \
# 0        1Fam            5       2003  ...            3            1
# 1        1Fam            8       1976  ...            3            1
# 2        1Fam            5       2001  ...            3            1
# 3        1Fam            5       1915  ...            3            1
# 4        1Fam            5       2000  ...            4            1
# ...       ...          ...        ...  ...          ...          ...
# 1455     1Fam            5       1999  ...            3            1
# 1456     1Fam            6       1978  ...            3            1
# 1457     1Fam            9       1941  ...            4            1
# 1458     1Fam            6       1950  ...            2            1
# 1459     1Fam            6       1965  ...            3            1
#
#      Fireplaces GarageType GarageCars PoolQC     Fence  MiscFeature  \
# 0             0     Attchd          2     NP  No Fence       Attchd
# 1             1     Attchd          2     NP  No Fence       Attchd
# 2             1     Attchd          2     NP  No Fence       Attchd
# 3             1     Detchd          3     NP  No Fence       Detchd
# 4             1     Attchd          3     NP  No Fence       Attchd
# ...         ...        ...        ...    ...       ...          ...
# 1455          1     Attchd          2     NP  No Fence       Attchd
# 1456          2     Attchd          2     NP     MnPrv       Attchd
# 1457          2     Attchd          1    NaN     GdPrv         Shed
# 1458          0     Attchd          1     NP  No Fence       Attchd
# 1459          0     Attchd          1     NP  No Fence       Attchd
#
#       SaleCondition  SalePrice
# 0            Normal     208500
# 1            Normal     181500
# 2            Normal     223500
# 3           Abnorml     140000
# 4            Normal     250000
# ...             ...        ...
# 1455         Normal     175000
# 1456         Normal     210000
# 1457         Normal     266500
# 1458         Normal     142125
# 1459         Normal     147500
#
# [1460 rows x 28 columns]

# %%
df.shape
# Out:
# (1460, 28)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Utilities', 'Neighborhood', 'BldgType', 'OverallCond', 'YearBuilt',
#        'Foundation', 'BsmtCond', 'BsmtExposure', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'FullBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'Fireplaces', 'GarageType', 'GarageCars', 'PoolQC', 'Fence',
#        'MiscFeature', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
#Data Cleaning

# %%
# Removing the columns as required

# %%
housing_prices = df[['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
        'Utilities','Neighborhood','BldgType','OverallCond', 'YearBuilt','Foundation',
       'BsmtCond', 'BsmtExposure','Heating','HeatingQC', 'CentralAir', 'Electrical','FullBath',
       'BedroomAbvGr', 'KitchenAbvGr','Fireplaces','GarageType','GarageCars','PoolQC',
       'Fence', 'MiscFeature','SaleCondition', 'SalePrice']]

# %%
# Dropping Null values

# %%
housing_prices['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', 'No Basement', 'Fa', 'Po'], dtype=object)

# %%
for i in range(len(housing_prices['BsmtCond'])):
    if housing_prices['BsmtCond'][i] == "No":
        housing_prices['BsmtCond'][i] = housing_prices['BsmtCond'][i].replace("No","No Basement")

# %%
housing_prices['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', 'No Basement', 'Fa', 'Po'], dtype=object)

# %%
housing_prices['GarageType'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'NG', 'Basment',
#        '2Types'], dtype=object)

# %%
for i in range(len(housing_prices['GarageType'])):
    if housing_prices['GarageType'][i] == "NP":
        housing_prices['GarageType'][i] = housing_prices['GarageType'][i].replace("NP","NG")

# %%
housing_prices['GarageType'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'NG', 'Basment',
#        '2Types'], dtype=object)

# %%
housing_prices['PoolQC'].unique()
# Out:
# array(['NP', nan, 'Ex', 'Fa', 'Gd'], dtype=object)

# %%
housing_prices['Fence'].unique()
# Out:
# array(['No Fence', 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
for i in range(len(housing_prices['Fence'])):
    if housing_prices['Fence'][i] == "NF":
        housing_prices['Fence'][i] = housing_prices['Fence'][i].replace("NF","No Fence")

# %%
housing_prices['Fence'].unique()
# Out:
# array(['No Fence', 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
housing_prices['MiscFeature'].unique()
# Out:
# array(['Attchd', 'Detchd', 'Shed', 'BuiltIn', 'NG', 'CarPort', 'Basment',
#        '2Types', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
for i in range(len(housing_prices['MiscFeature'])):
    if housing_prices['MiscFeature'][i] == "NO":
        housing_prices['MiscFeature'][i] = housing_prices['GarageType'][i].replace("NO","None")

# %%
housing_prices.shape
# Out:
# (1460, 28)

# %%
housing_prices.isnull().sum(axis=0)
# Out:
# MSSubClass        0
# MSZoning          0
# LotFrontage      15
# LotArea           0
# Street            0
# Utilities         0
# Neighborhood      0
# BldgType          0
# OverallCond       0
# YearBuilt         0
# Foundation        0
# BsmtCond          0
# BsmtExposure      0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# FullBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# Fireplaces        0
# GarageType        0
# GarageCars        0
# PoolQC           22
# Fence             0
# MiscFeature       0
# SaleCondition     0
# SalePrice         0
# dtype: int64

# %%
housing_prices = housing_prices.dropna(axis=0)
housing_prices = housing_prices.reset_index()

# %%
housing_prices.shape
# Out:
# (1427, 29)

# %%
# New Section

# %%
housing_prices.duplicated().value_counts()
# Out:
# False    1427
# dtype: int64

# %%
type(housing_prices)
# Out:
# pandas.core.frame.DataFrame

# %%
housing_prices.dtypes
# Out:
# index             int64
# MSSubClass        int64
# MSZoning         object
# LotFrontage      object
# LotArea           int64
# Street           object
# Utilities        object
# Neighborhood     object
# BldgType         object
# OverallCond       int64
# YearBuilt         int64
# Foundation       object
# BsmtCond         object
# BsmtExposure     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# FullBath          int64
# BedroomAbvGr      int64
# KitchenAbvGr      int64
# Fireplaces        int64
# GarageType       object
# GarageCars        int64
# PoolQC           object
# Fence            object
# MiscFeature      object
# SaleCondition    object
# SalePrice         int64
# dtype: object

# %%
housing_prices.to_csv("housing_prices_test.csv", index = False)

# %%
housing_prices
# Out:
#       index  MSSubClass MSZoning LotFrontage  LotArea Street Utilities  \
# 0         0          60       RL          65     8450   Pave    AllPub
# 1         1          20       RL          80     9600   Pave    AllPub
# 2         2          60       RL          68    11250   Pave    AllPub
# 3         3          70       RL          60     9550   Pave    AllPub
# 4         4          60       RL          84    14260   Pave    AllPub
# ...     ...         ...      ...         ...      ...    ...       ...
# 1422   1454          20       FV          62     7500   Pave    AllPub
# 1423   1455          60       RL          62     7917   Pave    AllPub
# 1424   1456          20       RL          85    13175   Pave    AllPub
# 1425   1458          20       RL          68     9717   Pave    AllPub
# 1426   1459          20       RL          75     9937   Pave    AllPub
#
#      Neighborhood BldgType  OverallCond  ...  BedroomAbvGr KitchenAbvGr  \
# 0         CollgCr     1Fam            5  ...             3            1
# 1         Veenker     1Fam            8  ...             3            1
# 2         CollgCr     1Fam            5  ...             3            1
# 3         Crawfor     1Fam            5  ...             3            1
# 4         NoRidge     1Fam            5  ...             4            1
# ...           ...      ...          ...  ...           ...          ...
# 1422      Somerst     1Fam            5  ...             2            1
# 1423      Gilbert     1Fam            5  ...             3            1
# 1424       NWAmes     1Fam            6  ...             3            1
# 1425        NAmes     1Fam            6  ...             2            1
# 1426      Edwards     1Fam            6  ...             3            1
#
#      Fireplaces GarageType GarageCars PoolQC     Fence MiscFeature  \
# 0             0     Attchd          2     NP  No Fence      Attchd
# 1             1     Attchd          2     NP  No Fence      Attchd
# 2             1     Attchd          2     NP  No Fence      Attchd
# 3             1     Detchd          3     NP  No Fence      Detchd
# 4             1     Attchd          3     NP  No Fence      Attchd
# ...         ...        ...        ...    ...       ...         ...
# 1422          0     Attchd          2     NP  No Fence      Attchd
# 1423          1     Attchd          2     NP  No Fence      Attchd
# 1424          2     Attchd          2     NP     MnPrv      Attchd
# 1425          0     Attchd          1     NP  No Fence      Attchd
# 1426          0     Attchd          1     NP  No Fence      Attchd
#
#       SaleCondition  SalePrice
# 0            Normal     208500
# 1            Normal     181500
# 2            Normal     223500
# 3           Abnorml     140000
# 4            Normal     250000
# ...             ...        ...
# 1422         Normal     185000
# 1423         Normal     175000
# 1424         Normal     210000
# 1425         Normal     142125
# 1426         Normal     147500
#
# [1427 rows x 29 columns]

# %%
numeric_cols = []
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        numeric_cols.append(col)

# %%
#Visualizing to get more Insight

# %%
sns.pairplot(data = housing_prices)

# %%
corr = housing_prices.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.title("Heat Map of all the Quantitative Values")
# Out:
# Text(0.5, 1.0, 'Heat Map of all the Quantitative Values')

# %%
#There is a very good co-relation between subclass,Lot area, Full bath. Sales prices is highly corelated with years built,Fullbath,Garage cars

# %%
sns.lmplot(x="YearBuilt", y="SalePrice", data=housing_prices);
plt.title("Linear Model Plot related to year built and saleprice")
# Out:
# Text(0.5, 1.0, 'Linear Model Plot related to year built and saleprice')

# %%
#Yearbuilt and sale price are co-related to each other, As the year increases the sale price increases,so for the new houses the salesprice increases.

# %%
sns.regplot(data = housing_prices, x ="KitchenAbvGr", y="FullBath")
plt.title("A plot to determine the relation between Linear feet of kitchen and Fullbath")
# Out:
# Text(0.5, 1.0, 'A plot to determine the relation between Linear feet of kitchen and Fullbath')

# %%
# For kitchens one or two the Fullbath rooms avilibility is not increasing and remains same.

# %%
sns.scatterplot(data = housing_prices, x ="MSSubClass", y="YearBuilt")
plt.title("Relation between type of dwelling and YearBuilt")
# Out:
# Text(0.5, 1.0, 'Relation between type of dwelling and YearBuilt')

# %%
#If MSSubclass less than 100 they are older homes are unfurnished home and if MSSubclass greater than 100 are newly built ones

# %%
sns.histplot(data =  housing_prices, x ="OverallCond", kde="LotFrontage", color="green")
plt.ylabel("Number of Lotfrontage")
plt.xlabel("Number of Overall Condition")
plt.title("Relation between overallcondition and Lotfrontage")
# Out:
# Text(0.5, 1.0, 'Relation between overallcondition and Lotfrontage')

# %%
# If the overall condition is 5, it is medium; the more Linear feet of street connected to property in lotfrontage, the higher.

# %%
sns.violinplot(data = housing_prices, y="YearBuilt")
# Out:
# <AxesSubplot:ylabel='YearBuilt'>

# %%
# The violin plot is considered for housing prices as the housing prices are increased from 1850 to 2025

# %%
sns.boxplot(data = housing_prices, x = "Foundation", y = "Fireplaces")
# Out:
# <AxesSubplot:xlabel='Foundation', ylabel='Fireplaces'>

# %%
#  If the house has only one fireplace, the foundation materials used are all the same.

# %%
plt.figure(figsize=(8,5))
values = housing_prices['BldgType'].value_counts()
labels = housing_prices['BldgType'].unique().tolist()
plt.pie(values,labels=labels,radius=1)
plt.title("Pie Chart of different Types of Buildings")
plt.show()

# %%
# According to the pie chart, the most common construction types are single-family houses (almost 80%) and townhouses with inside units(Twnhs) less than 1%.

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data = housing_prices['GarageType'])
plt.title("Line plot on Garage Types")
# Out:
# Text(0.5, 1.0, 'Line plot on Garage Types')

# %%
#The line plot allows us to see any patterns or trends in the data and make meaningful comparisons between the different garage types. In this particular plot, we can see that the mean sale price for properties with a garage type of "Attached" is significantly higher than the mean sale price for properties with other types of garages.

# %%
sns.barplot(data = housing_prices ['SalePrice'])
# Out:
# <AxesSubplot:>

# %%
# The plot shows the frequency of different sale price ranges, with each bar representing a different price range and the height of the bar indicating the number of properties within that range. The bar plot allows us to see the spread of the data and identify any patterns or trends. For example, we can see from the plot that the majority of properties in the dataset have a sale price between 100,000 and 200,000 dollars, with a smaller number of properties having sale prices above or below this range. Additionally, the bar plot highlights any outliers in the data, such as properties with exceptionally high or low sale prices.

# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=housing prices&'
       'apiKey=7e5b0bb5b2d147a3b66260545d763f2b')

response = requests.get(url)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
jsontxt = response.json()

# %%
response.content
# Out:
# b'{"status":"ok","totalResults":4444,"articles":[{"source":{"id":"cnn","name":"CNN"},"author":"Anna Bahney","title":"US home prices continued to lose momentum in November","description":"US home prices nudged higher in November, but the pace of that growth slowed, as rising mortgage rates pushed prospective buyers out of the housing market late last year.","url":"https://www.cnn.com/2023/01/31/homes/case-shiller-home-price-index-november/index.html","urlToImage":"https://media.cnn.com/api/v1/images/stellar/prod/230110141903-home-buying-preparation-restricted.jpg?c=16x9&q=w_800,c_fill","publishedAt":"2023-01-31T15:16:42Z","content":"US home prices nudged higher in November, but the pace of that growth slowed, as rising mortgage rates pushed prospective buyers out of the housing market late last year.\\r\\nHome prices rose 7.7% in No\xe2\x80\xa6 [+1522 chars]"},{"source":{"id":"cnn","name":"CNN"},"author":"Anna Bahney","title":"Here are the US cities where home prices are actually falling","description":"Home prices are going up across the country \xe2\x80\x94 in aggregate. Looking at individual markets, however, some are showing prices have fallen from a year ago.","url":"https://www.cnn.com/2023/02/19/homes/housing-prices-2022-fourth-quarter/index.html","urlToImage":"https://media.cnn.com/api/v1/images/stellar/prod/230217152113-austin-tx-home-prices-file-restricted.jpg?c=16x9&q=w_800,c_fill","publishedAt":"2023-02-19T10:08:44Z","content":"Home prices are going up across the country in aggregate. Looking at individual markets, however, some are showing prices have fallen from a year ago.\\r\\nSingle-family median home prices increased 4% i\xe2\x80\xa6 [+6457 chars]"},{"source":{"id":"engadget","name":"Engadget"},"author":"Will Shanklin","title":"Google Fiber launches 5Gbps service for $125 per month","description":"Google Fiber is launching the 5Gbps internet plan it began testing in October. The service will initially cover four cities, but Google says the $125-per-month service will expand to other areas later this year.The new plan is available today in Kansas City,W\xe2\x80\xa6","url":"https://www.engadget.com/google-fiber-launches-5gbps-service-for-125-per-month-214732336.html","urlToImage":"https://s.yimg.com/os/creatr-uploaded-images/2023-02/aa5acaf0-acad-11ed-bcef-2a3b28acce0e","publishedAt":"2023-02-14T21:47:32Z","content":"Google Fiber is launching the 5Gbps internet plan it began testing in October. The service will initially cover four cities, but Google says the $125-per-month service will expand to other areas late\xe2\x80\xa6 [+1274 chars]"},{"source":{"id":null,"name":"The Guardian"},"author":"Graeme Wearden","title":"UK property asking prices stagnating, lifting hopes of softer landing for housing market \xe2\x80\x93 business live","description":"UK property asking prices rose by just \xc2\xa314 in February, weakest gain on record, Rightmove reports, with sellers \xe2\x80\x98more realistic\xe2\x80\x99 about what property is worth<ul><li>Loss of nearly 15,000 UK retail jobs a \xe2\x80\x98brutal start to 2023\xe2\x80\x99, report says</li></ul>Demand fro\xe2\x80\xa6","url":"https://www.theguardian.com/business/live/2023/feb/20/uk-property-asking-prices-housing-market-ftse-stock-markets-eurozone-economy-business-live","urlToImage":"https://i.guim.co.uk/img/media/1b92420452cf4d8d61205b71b247a85d9e8f8891/0_295_4500_2700/master/4500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctbGl2ZS5wbmc&enable=upscale&s=3c59e77c4b0df5f940492e67e0ad65f1","publishedAt":"2023-02-20T07:55:45Z","content":"Introduction: Average price tag on a home rose by just \xc2\xa314 in February\\r\\nGood morning, and welcome to our rolling coverage of business, the financial markets and the world economy.\\r\\nUK house prices re\xe2\x80\xa6 [+4216 chars]"},{"source":{"id":null,"name":"The Guardian"},"author":"Will Hutton","title":"Exorbitant hou ...

# %%
filename="Housing_Prices_Headlines.csv"
MyFILE=open(filename,"w")
WriteThis="Date,Source,Title,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
MyFILE=open(filename, "a")

# %%
import re
for items in jsontxt["articles"]:
    Source=items["source"]["id"]    
    Date=items["publishedAt"]
    NewDate=Date.split("T")
    Date=NewDate[0]
    ## CLEAN the Title
    ##Replace punctuation with space
    # Accept one or more copies of punctuation         
    # plus zero or more copies of a space
    # and replace it with a single space
    Title=items["title"]
    Title=re.sub(r'[,.;@#?!&$\-\']+', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(' +', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(r'\"', ' ', Title, flags=re.IGNORECASE)
    
    # and replace it with a single space
    ## NOTE: Using the "^" on the inside of the [] means
    ## we want to look for any chars NOT a-z or A-Z and replace
    ## them with blank. This removes chars that should not be there.
    Title=re.sub(r'[^a-zA-Z]', " ", Title, flags=re.VERBOSE)
    Title=Title.replace(',', '')
    Title=' '.join(Title.split())
    Title=re.sub("\n|\r", "", Title)
    ##----------------------------------------------------------
    
    Headline=items["description"]
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", str(Headline), flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if len(wd)>3])
    WriteThis=str(Date)+","+str(Source)+","+ str(Title) + "," + str(Headline) + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
housing_prices_api = pd.read_csv(filename, error_bad_lines=False)
print(housing_prices_api.head())
# iterating the columns 
for col in housing_prices_api.columns: 
    print(col) 
    
print(housing_prices_api["Headline"])

## REMOVE any rows with NaN in them
housing_prices_api = housing_prices_api.dropna()
print(housing_prices_api["Headline"])

### Tokenize and Vectorize the Headlines
## Create the list of headlines
HeadlineLIST = []
for next1 in housing_prices_api["Headline"]:
    HeadlineLIST.append(next1)

print("The headline list is")
print(HeadlineLIST)
# Out:
#          Date    Source                                              Title  \
# 0  2023-01-31       cnn  US home prices continued to lose momentum in N...
# 1  2023-02-19       cnn  Here are the US cities where home prices are a...
# 2  2023-02-14  engadget   Google Fiber launches Gbps service for per month
# 3  2023-02-20      None  UK property asking prices stagnating lifting h...
# 4  2023-02-05      None  Exorbitant house prices don t just hurt the yo...
#
#                                             Headline
# 0  home prices nudged higher November pace that g...
# 1  Home prices going across country aggregate Loo...
# 2  Google Fiber launching Gbps internet plan bega...
# 3  property asking prices rose just February weak...
# 4  Steps change unfair landscape include ending r...
# Date
# Source
# Title
# Headline
# 0     home prices nudged higher November pace that g...
# 1     Home prices going across country aggregate Loo...
# 2     Google Fiber launching Gbps internet plan bega...
# 3     property asking prices rose just February weak...
# 4     Steps change unfair landscape include ending r...
#                             ...
# 95    Sadiq Khan free school meal plan ought start s...
# 96                                                 None
# 97    Strong receipts boosted public finances last m...
# 98    shopping your first home consider best housing...
# 99    Annington Property launches judicial review ar...
# Name: Headline, Length: 100, dtype: object
# 0     home prices nudged higher November pace that g...
# 1     Home prices going across country aggregate Loo...
# 2     Google Fiber launching Gbps internet plan bega...
# 3     property asking prices rose just February weak...
# 4     Steps change unfair landscape include ending r...
#                             ...
# 95    Sadiq Khan free school meal plan ought start s...
# 96                                                 None
# 97    Strong receipts boosted public finances last m...
# 98    shopping your first home consider best housing...
# 99    Annington Property launches judicial review ar...
# Name: Headline, Length: 100, dtype: object
# The headline list is
# ['home prices nudged higher November pace that growth slowed rising mortgage rates pushed prospective buyers housing market late last year', 'Home prices going across country aggregate Looking individual markets however some showing prices have fallen from year', 'Google Fiber launching Gbps internet plan began testing October service will initially cover four cities Google says month service will expand other areas later this year plan available today Kansas City', 'property asking prices rose just February weakest gain record Rightmove reports with sellers more realistic about what property worth Loss nearly retail jobs brutal start report says Demand', 'Steps change unfair landscape include ending right taxing residential property today prices building vital social housing Housing policy killing British civilisation said interlocutor Right been social catastrophe', 'Federal Reserve policy based trust central bank ability maintain stable prices depends public confidence that deliver after more than year interest rate hikes attempts cool economy prices still rising', 'single family home price growth cooled further November surveys showed Tuesday which together with declining mortgage rates could help slow housing market slide deeper into recession', 'Dave Liniger founded ReMax brokerage with real estate agents expects housing market cool further', 'Housing market veteran Jeff Taylor told Insider expects trading volume real estate sector track fall year', 'Mortgage rates slipped after softer rate hike this week sign that conditions housing market easing slightly', 'time start worrying rolling recessions tech housing spread into other parts economy', 'Insider Phil Rosen explains what latest housing lumber data suggest home market', 'Housebuilder reports modest uplift reservations homes January remains cautiousBritain largest housebuilder Barratt Developments reported grounds optimism housing market after increase sales January', 'Vail Colorado expensive housing burdening people from small business owners teachers solutions dwindle', 'homes lost their value marking largest June December drop percentage terms since according Redfin', 'British house prices dropped bigger than expected January below their peak August following surge borrowing costs broader inflation pressures mortgage lender Nationwide Building Society said Wednesday', 'Home Depot expects flat sales slimmer profits this year rising prices higher borrowing costs portfolio pain erode demand', 'typical Francisco homeowner still paying over each month their homes even after mortgage rates peaked October', 'Argentina government desperately trying tame soaring prices economists expect year year inflation near much', 'Property market defied gravity years analysts rising mortgage rates will mirror price crashBritain estate agents normally radiate optimism they will watching anxiously noon next Thursday when Bank England expect', 'Once pandemic boom town Phoenix poster child housing downturn numerous indicators point peril real estate market', 'region popularity seen surge sending real estate prices soaring pushing locals', 'Small midsize rural communities some biggest increases home prices first years pandemic driven town buyers', 'Rolling coverage latest economic financial news housebuilder Barratt says economic backdrop clearly been challenging households suffer blow finances this year says report Charlie Huggins Head Equities', 'Homes sitting market more than days purchased around less than original list price', 'least million people plan real estate these markets have shown significant resilience home prices decline nationwide', 'Mortgage rates have dropped over past months holding steady today Rates will likely continue fall inflation cools', 'Victor Zubriski said ditching South Florida because surge popularity made unlivable from housing costs pollution', 'homebuilders January momentum proves sustainable many lumber suppliers could caught flat footed Raymond James sa ...
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\337385678.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   housing_prices_api = pd.read_csv(filename, error_bad_lines=False)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rissh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

# %%
import numpy as np
def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I | re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc


normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(HeadlineLIST)

# %%
temp = pd.DataFrame()

# %%
temp_1 = temp.append(norm_corpus[0].split()).T
for i in range(1,len(norm_corpus)):
    temp_2 = temp.append(norm_corpus[i].split()).T
    temp_1 = pd.concat([temp_1,temp_2])
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_1 = temp.append(norm_corpus[0].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T

# %%
temp_1['label'] = 'housing_prices'
temp_1
# Out:
#             0         1          2          3         4          5         6  \
# 0        home    prices     nudged     higher  november       pace    growth
# 0        home    prices      going     across   country  aggregate   looking
# 0      google     fiber  launching       gbps  internet       plan     began
# 0    property    asking     prices       rose  february    weakest      gain
# 0       steps    change     unfair  landscape   include     ending     right
# ..        ...       ...        ...        ...       ...        ...       ...
# 0       sadiq      khan       free     school      meal       plan     ought
# 0        none       NaN        NaN        NaN       NaN        NaN       NaN
# 0      strong  receipts    boosted     public  finances       last     month
# 0    shopping     first       home   consider      best    housing   markets
# 0   annington  property   launches   judicial    review    arguing  ministry
#
#              7            8         9  ...            20       21  \
# 0       slowed       rising  mortgage  ...           NaN      NaN
# 0   individual      markets   however  ...           NaN      NaN
# 0      testing      october   service  ...         later     year
# 0       record    rightmove   reports  ...        report     says
# 0       taxing  residential  property  ...  civilisation     said
# ..         ...          ...       ...  ...           ...      ...
# 0        start    something     bigat  ...       primary   school
# 0          NaN          NaN       NaN  ...           NaN      NaN
# 0    inflation        drove      debt  ...       earlier    share
# 0        first         time    buyers  ...           NaN      NaN
# 0        right         take      back  ...         hands  started
#
#               22         23      24           25         26       27     28  \
# 0            NaN        NaN     NaN          NaN        NaN      NaN    NaN
# 0            NaN        NaN     NaN          NaN        NaN      NaN    NaN
# 0           plan  available   today       kansas       city      NaN    NaN
# 0         demand        NaN     NaN          NaN        NaN      NaN    NaN
# 0   interlocutor      right  social  catastrophe        NaN      NaN    NaN
# ..           ...        ...     ...          ...        ...      ...    ...
# 0          pupil       free  school        meals  september  welcome  shift
# 0            NaN        NaN     NaN          NaN        NaN      NaN    NaN
# 0        economy        NaN     NaN          NaN        NaN      NaN    NaN
# 0            NaN        NaN     NaN          NaN        NaN      NaN    NaN
# 0          court     battle   block     reversal     highly      NaN    NaN
#
#              label
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# ..             ...
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
# 0   housing_prices
#
# [100 rows x 30 columns]

# %%
# inflation

# %%
test = pd.read_csv ("Housing_Prices_Headlines.csv")
test.head()
# Out:
#          Date    Source                                              Title  \
# 0  2023-01-31       cnn  US home prices continued to lose momentum in N...
# 1  2023-02-19       cnn  Here are the US cities where home prices are a...
# 2  2023-02-14  engadget   Google Fiber launches Gbps service for per month
# 3  2023-02-20      None  UK property asking prices stagnating lifting h...
# 4  2023-02-05      None  Exorbitant house prices don t just hurt the yo...
#
#                                             Headline
# 0  home prices nudged higher November pace that g...
# 1  Home prices going across country aggregate Loo...
# 2  Google Fiber launching Gbps internet plan bega...
# 3  property asking prices rose just February weak...
# 4  Steps change unfair landscape include ending r...

# %%
test.dtypes
# Out:
# Date        object
# Source      object
# Title       object
# Headline    object
# dtype: object

# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q= housing market&'
       'apiKey=7e5b0bb5b2d147a3b66260545d763f2b')

response = requests.get(url)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
jsontxt = response.json()

# %%
response.content
# Out:
# b'{"status":"ok","totalResults":7575,"articles":[{"source":{"id":"cnn","name":"CNN"},"author":"Anna Bahney","title":"US home prices continued to lose momentum in November","description":"US home prices nudged higher in November, but the pace of that growth slowed, as rising mortgage rates pushed prospective buyers out of the housing market late last year.","url":"https://www.cnn.com/2023/01/31/homes/case-shiller-home-price-index-november/index.html","urlToImage":"https://media.cnn.com/api/v1/images/stellar/prod/230110141903-home-buying-preparation-restricted.jpg?c=16x9&q=w_800,c_fill","publishedAt":"2023-01-31T15:16:42Z","content":"US home prices nudged higher in November, but the pace of that growth slowed, as rising mortgage rates pushed prospective buyers out of the housing market late last year.\\r\\nHome prices rose 7.7% in No\xe2\x80\xa6 [+1522 chars]"},{"source":{"id":null,"name":"The Guardian"},"author":"Joanna Partridge","title":"Grounds for optimism in UK housing market, says Barratt","description":"Housebuilder reports \xe2\x80\x98modest uplift\xe2\x80\x99 in reservations of new homes in January but remains cautiousBritain\xe2\x80\x99s largest housebuilder, Barratt Developments, has reported grounds for optimism in the UK housing market after an increase in sales in January \xe2\x80\x93 but it sa\xe2\x80\xa6","url":"https://www.theguardian.com/business/2023/feb/08/grounds-for-optimism-in-uk-housing-market-says-barratt","urlToImage":"https://i.guim.co.uk/img/media/4e17e973675b6beeac32f62e2ba55a9f22386459/17_102_3043_1826/master/3043.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=2bab27d8a45118b58c2fc4697b813e7c","publishedAt":"2023-02-08T12:44:25Z","content":"Britains largest housebuilder, Barratt Developments, has reported grounds for optimism in the UK housing market after an increase in sales in January but it said the trading outlook for 2023 remains \xe2\x80\xa6 [+3581 chars]"},{"source":{"id":"business-insider","name":"Business Insider"},"author":"prosen@insider.com (Phil Rosen)","title":"Here\'s why the housing market could see more action this year - and what it means for affordability","description":"Insider\'s Phil Rosen explains what the latest housing and lumber data suggest for the home market in 2023.","url":"https://www.businessinsider.com/the-housing-market-probably-wont-get-more-affordable-this-year-2023-1","urlToImage":"https://i.insider.com/63d41d664589790018e587e3?width=1200&format=jpeg","publishedAt":"2023-01-30T11:00:00Z","content":"Welcome back, readers Phil Rosen here. On this day 54 years ago, the Beatles played their last-ever gig on a rooftop in London.\xc2\xa0\\r\\nAnd just the same, today marks my last Monday writing to you from Cal\xe2\x80\xa6 [+4633 chars]"},{"source":{"id":"reuters","name":"Reuters"},"author":null,"title":"U.S. pending home sales post first gain in seven months in December - Reuters.com","description":"Contracts to buy U.S. previously owned homes increased for the first time in seven months in December as mortgage rates declined, another hopeful sign that the embattled housing market was starting to stabilize.","url":"https://www.reuters.com/markets/us/us-pending-home-sales-post-first-gain-seven-months-december-2023-01-27/","urlToImage":"https://www.reuters.com/resizer/x8hh8a11lzLl-6X-v0SzoMmEK7o=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/JTGCEG3BM5NKNFVDNXWWE6IZHA.jpg","publishedAt":"2023-01-27T15:08:00Z","content":"WASHINGTON, Jan 27 (Reuters) - Contracts to buy U.S. previously owned homes increased for the first time in seven months in December as mortgage rates declined, another hopeful sign that the embattle\xe2\x80\xa6 [+1635 chars]"},{"source":{"id":"business-insider","name":"Business Insider"},"author":"jsor@insider.com (Jennifer Sor)","title":"Mortgage rates are falling back nea ...

# %%
filename="housing_market_headlines.csv"
MyFILE=open(filename,"w")
WriteThis="Date,Source,Title,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
MyFILE=open(filename, "a")

# %%
import re
for items in jsontxt["articles"]:
    Source=items["source"]["id"]    
    Date=items["publishedAt"]
    NewDate=Date.split("T")
    Date=NewDate[0]
    ## CLEAN the Title
    ##Replace punctuation with space
    # Accept one or more copies of punctuation         
    # plus zero or more copies of a space
    # and replace it with a single space
    Title=items["title"]
    Title=re.sub(r'[,.;@#?!&$\-\']+', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(' +', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(r'\"', ' ', Title, flags=re.IGNORECASE)
    
    # and replace it with a single space
    ## NOTE: Using the "^" on the inside of the [] means
    ## we want to look for any chars NOT a-z or A-Z and replace
    ## them with blank. This removes chars that should not be there.
    Title=re.sub(r'[^a-zA-Z]', " ", Title, flags=re.VERBOSE)
    Title=Title.replace(',', '')
    Title=' '.join(Title.split())
    Title=re.sub("\n|\r", "", Title)
    ##----------------------------------------------------------
    
    Headline=items["description"]
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', str(Headline), flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", str(Headline), flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if len(wd)>3])
    WriteThis=str(Date)+","+str(Source)+","+ str(Title) + "," + str(Headline) + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
housing_market_api = pd.read_csv(filename, error_bad_lines=False)
print(housing_market_api.head())
# iterating the columns 
for col in housing_market_api.columns: 
    print(col) 
    
print(housing_market_api["Headline"])

## REMOVE any rows with NaN in them
housing_market_api = housing_market_api.dropna()
print(housing_market_api["Headline"])

### Tokenize and Vectorize the Headlines
## Create the list of headlines
HeadlineLIST = []
for next1 in housing_market_api["Headline"]:
    HeadlineLIST.append(next1)

print("The headline list is")
print(HeadlineLIST)
# Out:
#          Date            Source  \
# 0  2023-01-31               cnn
# 1  2023-02-08              None
# 2  2023-01-30  business-insider
# 3  2023-01-27           reuters
# 4  2023-02-03  business-insider
#
#                                                Title  \
# 0  US home prices continued to lose momentum in N...
# 1  Grounds for optimism in UK housing market says...
# 2  Here s why the housing market could see more a...
# 3  U S pending home sales post first gain in seve...
# 4  Mortgage rates are falling back near reopening...
#
#                                             Headline
# 0  home prices nudged higher November pace that g...
# 1  Housebuilder reports modest uplift reservation...
# 2  Insider Phil Rosen explains what latest housin...
# 3  Contracts previously owned homes increased fir...
# 4  Mortgage rates slipped after softer rate hike ...
# Date
# Source
# Title
# Headline
# 0     home prices nudged higher November pace that g...
# 1     Housebuilder reports modest uplift reservation...
# 2     Insider Phil Rosen explains what latest housin...
# 3     Contracts previously owned homes increased fir...
# 4     Mortgage rates slipped after softer rate hike ...
#                             ...
# 95    proposes turn California zoning system into so...
# 96    Some worst that have seen been here Kwajo Twen...
# 97    Jamie Dimon Jeremy Siegel other experts Wall S...
# 98    Build Rent becoming increasingly popular what ...
# 99                                                 None
# Name: Headline, Length: 100, dtype: object
# 0     home prices nudged higher November pace that g...
# 1     Housebuilder reports modest uplift reservation...
# 2     Insider Phil Rosen explains what latest housin...
# 3     Contracts previously owned homes increased fir...
# 4     Mortgage rates slipped after softer rate hike ...
#                             ...
# 95    proposes turn California zoning system into so...
# 96    Some worst that have seen been here Kwajo Twen...
# 97    Jamie Dimon Jeremy Siegel other experts Wall S...
# 98    Build Rent becoming increasingly popular what ...
# 99                                                 None
# Name: Headline, Length: 100, dtype: object
# The headline list is
# ['home prices nudged higher November pace that growth slowed rising mortgage rates pushed prospective buyers housing market late last year', 'Housebuilder reports modest uplift reservations homes January remains cautiousBritain largest housebuilder Barratt Developments reported grounds optimism housing market after increase sales January', 'Insider Phil Rosen explains what latest housing lumber data suggest home market', 'Contracts previously owned homes increased first time seven months December mortgage rates declined another hopeful sign that embattled housing market starting stabilize', 'Mortgage rates slipped after softer rate hike this week sign that conditions housing market easing slightly', 'Once pandemic boom town Phoenix poster child housing downturn numerous indicators point peril real estate market', 'Falling mortgage rates have provided boost housing market more buyers able find affordability thanks today lower rates', 'Dave Liniger founded ReMax brokerage with real estate agents expects housing market cool further', 'Housing market veteran Jeff Taylor told Insider expects trading volume real estate sector track fall year', 'Rolling coverage latest economic financial news housebuilder Barratt says economic backdrop clearly been challenging households suffer blow finances this year says report Charlie Huggins Head Equities', 'property asking prices rose just February weakest gain record Rightmove reports with sellers more realistic about what property worth Loss nearly retail jobs brutal start report says Demand', 'time year when Samsung trots latest flagship lineup smartphones annual wintertime Unpacked event This year Galaxy flagships merely incremental updates Samsung smartphone portfolio they still quite', 'bursting global housing bubble likely have more painful economic knock effect than decline equities Grantham said', 'single family home price growth cooled further November surveys showed Tuesday which together with declining mortgage rates could help slow housing market slide deeper into recession', 'time start worrying rolling recessions tech housing spread into other parts economy', 'Homes sitting market more than days purchased around less than original list price', 'homes lost their value marking largest June December drop percentage terms since according Redfin', 'typical Francisco homeowner still paying over each month their homes even after mortgage rates peaked October', 'Housing companies will blocked from development work unless they agree cladding removal other repairs unsafe multi storey buildings bill totalling billion pounds billion British government said Monday', 'Vail Colorado expensive housing burdening people from small business owners teachers solutions dwindle', 'Mortgage rates have dropped over past months holding steady today Rates will likely continue fall inflation cools', 'Some people paying only month rent explore options that could help housing costsThe cost renting home soared prompting tenants seek cheaper options that could save some thousands pounds year during cost', 'Authorities French capital also want more affordable housing working middle class familiesParis authorities have proposed combat population drain from French capital pushing higher taxes second home owners introducing more', 'Remote work emptied downtowns across that space could used create desperately needed affordable housing lack affordable housing emptying many downtowns what doctors might call comorbidities different', 'Steps change unfair landscape include ending right taxing residential property today prices building vital social housing Housing policy killing British civilisation said interlocutor Right been social catastrophe', 'Federal Reserve continues inflation fighting tightrope market moves suggest that investors feeling more ease with central bank actions That necessarily good thing', 'Home prices going across country aggregate Looking individual markets however some showing prices have fallen f ...
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\2924245829.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   housing_market_api = pd.read_csv(filename, error_bad_lines=False)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rissh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

# %%
import numpy as np
def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I | re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc


normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(HeadlineLIST)

# %%
norm_corpus
# Out:
# array(['home prices nudged higher november pace growth slowed rising mortgage rates pushed prospective buyers housing market late last year',
#        'housebuilder reports modest uplift reservations homes january remains cautiousbritain largest housebuilder barratt developments reported grounds optimism housing market increase sales january',
#        'insider phil rosen explains latest housing lumber data suggest home market',
#        'contracts previously owned homes increased first time seven months december mortgage rates declined another hopeful sign embattled housing market starting stabilize',
#        'mortgage rates slipped softer rate hike week sign conditions housing market easing slightly',
#        'pandemic boom town phoenix poster child housing downturn numerous indicators point peril real estate market',
#        'falling mortgage rates provided boost housing market buyers able find affordability thanks today lower rates',
#        'dave liniger founded remax brokerage real estate agents expects housing market cool',
#        'housing market veteran jeff taylor told insider expects trading volume real estate sector track fall year',
#        'rolling coverage latest economic financial news housebuilder barratt says economic backdrop clearly challenging households suffer blow finances year says report charlie huggins head equities',
#        'property asking prices rose february weakest gain record rightmove reports sellers realistic property worth loss nearly retail jobs brutal start report says demand',
#        'time year samsung trots latest flagship lineup smartphones annual wintertime unpacked event year galaxy flagships merely incremental updates samsung smartphone portfolio still quite',
#        'bursting global housing bubble likely painful economic knock effect decline equities grantham said',
#        'single family home price growth cooled november surveys showed tuesday together declining mortgage rates could help slow housing market slide deeper recession',
#        'time start worrying rolling recessions tech housing spread parts economy',
#        'homes sitting market days purchased around less original list price',
#        'homes lost value marking largest june december drop percentage terms since according redfin',
#        'typical francisco homeowner still paying month homes even mortgage rates peaked october',
#        'housing companies blocked development work unless agree cladding removal repairs unsafe multi storey buildings bill totalling billion pounds billion british government said monday',
#        'vail colorado expensive housing burdening people small business owners teachers solutions dwindle',
#        'mortgage rates dropped past months holding steady today rates likely continue fall inflation cools',
#        'people paying month rent explore options could help housing coststhe cost renting home soared prompting tenants seek cheaper options could save thousands pounds year cost',
#        'authorities french capital also want affordable housing working middle class familiesparis authorities proposed combat population drain french capital pushing higher taxes second home owners introducing',
#        'remote work emptied downtowns across space could used create desperately needed affordable housing lack affordable housing emptying many downtowns doctors might call comorbidities different',
#        'steps change unfair landscape include ending right taxing residential property today prices building vital social housing housing policy killing british civilisation said interlocutor right social catastrophe',
#        'federal reserve continues inflation fighting tightrope market moves suggest investors feeling ease central bank actions necessarily good thing',
#        'home prices going across country aggregate looking individual markets however showing prices fallen year',
#        'arrivals welcomed housed manhattan hotel upon arrival warehoused frigid corner brooklynalejandro landaeta walking local store grab lunch stepped brooklyn warehouse',
#        'christian ogata home builder offered mortgage rate first year loan trend becoming common real estate market',
#        'british house prices dropped bigger expected january peak august following surge borrowing costs broader inflation pressures mortgage lender nationwide building society said wednesday',
#        'think improvement attests ongoing desire homeownership exists country pultegroup ryan marshall said',
#        'francisco york slumping pandemic boom fizzles migration florida boosted miami',
#        'insider phil rosen breaks stocks could stage rally meaning bullish bond market metric',
#        'tiny home craze taking golden state could spread across america lawmakers ponder benefits accessory dwelling units',
#        'market veteran yardeni said need spark recession ease consumer price pressures urging central bank relax policy',
#        'amid debate happening housing market options grip mortgage price according experts probably feel like staring barrel much higher monthly payments',
#        'none',
#        'insider phil rosen speaks experts federal reserve rate hike could impact stocks market volatility',
#        'demand homes gone throughout country particularly certain places seattle tampa florida',
#        'signs tanking inflation everywhere finally starting acknowledge fundstrat said',
#        'homeless charity fight rent arrears adds property funds woes including rising interest rates sceptical investorsmatt fearnley charity owes almost rent landlord bill likely keep growing unless long list',
#        'least million people plan real estate markets shown significant resilience home prices decline nationwide',
#        'protections impact million households come time demand rental units near time high',
#        'none', 'bizarre rental system helping',
#        'refinance rates mixed rate ticked interest rate hikes affected refinance market',
#        'several benchmark refinance rates last week interest rate hikes affected refinance market',
#        'country biggest landlords billion investment firm primarily increased efforts evict tenants georgia florida',
#        'annual house price growth slows federal reserve expected raise rates markets wonder whether pausegood morning welcome rolling coverage business world economy financial markets',
#        'blaming housing crisis hedge funds private equity easy dead wrong',
#        'federal reserve chairman jerome powell said wednesday fully sure central bank stop rate rises presses forward efforts cool inflation',
#        'gold price jumps chair powell talks disinflation warns early declare victory kitco news federal reserve hikes interest rate signals come news stock market live news upda',
#        'property market defied gravity years analysts rising mortgage rates mirror price crashbritain estate agents normally radiate optimism watching anxiously noon next thursday bank england expect',
#        'announced three winners european social innovation competition eusic seeks find pioneering solutions societal challenges challenge named future living designed attract participants advan',
#        'small midsize rural communities biggest increases home prices first years pandemic driven town buyers',
#        'homebuilders january momentum proves sustainable many lumber suppliers could caught flat footed raymond james said',
#        'mother three struggle clarion reflects system rigged favour asset owners renters abandonedyou read grim facts chanel sultan life minute first talk dreams like degree',
#        'refinance rates mixed week rate tapered interest rate hikes affected refinance market',
#        'india government provide incentives urban civic bodies improve finances credit worthiness help raise funds municipal bonds finance minister said wednesday',
#        'sweden banks highly exposed commercial real estate sector makes main risk financial stability central bank governor erik thedeen told parliament finance committee regular testimony',
#        'home depot expects flat sales slimmer profits year rising prices higher borrowing costs portfolio pain erode demand',
#        'mortgage rates remain today rates continue fall homebuyers likely start enter market',
#        'freeze replaced solutions housing crisis work need permanentdundee sometimes troubled often picturesque city scotland east coast generally carried reputation affordability even',
#        'markets rallied year investors believe inflation continue ease economy avoid recession could tears',
#        'last year million displaced millions follow neither government housing market readyover past decade experienced succession monumental climate disasters hurricanes obliterated',
#        'black swan author nassim taleb hedge fund long predicted crash warning rising debt levels pose timebomb markets',
#        'corner cutting contractors sold buildings safe collapsed culpable officials offered permits controlsthe death toll devastating earthquakes turkey syria surpassed tens thousands',
#        'river nice believe stock market ethical help clients discover harm reducing techniques lead ethical investments',
#        'interest rate buydowns come reduced profit sellers worthwhile unpredictable real estate market',
#        'insider phil rosen explains bond market giving positive vibes rest year',
#        'bear markets historically resulted leadership change suggests economy sectors likely winners cycle',
#        'effect prices first months people upset jeremy siegel said tuesday inflation report',
#        'inflation print would likely pull yields lower along dollar boost risk assets jpmorgan said',
#        'federal reserve href markets rates bonds expected deliver small rate hike keep anti inflation tilt raised target interest rate quarter percentage point wednesday continued promise ongoing increases',
#        'federal reserve policy based trust central bank ability maintain stable prices depends public confidence deliver year interest rate hikes attempts cool economy prices still rising',
#        'experts sounding alarm stocks economy rising interest rates heap pressure asset prices demand',
#        'martin lyster suggests dismantling mechanisms concentrate wealth naomi roberts calls taxes include modestly richyour editorial january calls wealth taxes address extreme inequality sticking plaster',
#        'florida canary coal mine climate change long time residents already fleeing scary omen rest',
#        'none',
#        'home prices declining pandemic melt news current real estate investors good news prospective ones',
#        'none',
#        'jeremy siegel stood forecast stock price could soar upwards year even economy enters mild recession',
#        'none',
#        'rolling coverage latest economic financial news treasury committee prepares quiz officials morning property demand declines house prices england fall sunak expand free childcare tackle workforce',
#        'financial markets week latched federal reserve chair jerome powell called welcome disinflation betting signals central bank high inflation nearing',
#        'renewable strong steel astonishingly fireproof easy quiet build could timber construction save planet step inside revolutionary london workplace everyone wants touchthere little',
#        'consumer spending fell december putting economy lower growth path heading inflation continued subside could give federal reserve room slow pace interest rate hikes next week',
#        'company million state program build tiny home shelters long beach california',
#        'none',
#        'minutes centre italy visited cities sant ambrogio district managed stay tourist radar locals market square tell makes specialthe florentine neighbourhood sant ambrogio',
#        'bank england poised raise interest rates time thursday keep fight rampant inflation might also drop hint steep climb borrowing costs',
#        'investors bought billion phoenix properties backing leaving opportunities regular people',
#        'insider phil rosen sits media personality chairman leary ventures talk investment openai',
#        'region popularity seen surge sending real estate prices soaring pushing locals',
#        'insider phil rosen compares enthusiasm meme stock mania explains latest comments',
#        'proposes turn california zoning system something like japan days',
#        'worst seen kwajo tweneboa said visit york city',
#        'jamie dimon jeremy siegel experts wall street weighed odds avoiding recession',
#        'build rent becoming increasingly popular good tips make build rent perfect passive income stream',
#        'none'], dtype='<U208')

# %%
temp = pd.DataFrame()

# %%
temp_3 = temp.append(norm_corpus[0].split()).T
for i in range(1,len(norm_corpus)):
    temp_4 = temp.append(norm_corpus[i].split()).T
    temp_3 = pd.concat([temp_3,temp_4])
# Out:
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_3 = temp.append(norm_corpus[0].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\rissh\AppData\Local\Temp\ipykernel_34024\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T

# %%
temp_3['label'] = 'housing_market'
temp_3
# Out:
#                0           1           2             3             4  \
# 0           home      prices      nudged        higher      november
# 0   housebuilder     reports      modest        uplift  reservations
# 0        insider        phil       rosen      explains        latest
# 0      contracts  previously       owned         homes     increased
# 0       mortgage       rates     slipped        softer          rate
# ..           ...         ...         ...           ...           ...
# 0       proposes        turn  california        zoning        system
# 0          worst        seen       kwajo      tweneboa          said
# 0          jamie       dimon      jeremy        siegel       experts
# 0          build        rent    becoming  increasingly       popular
# 0           none         NaN         NaN           NaN           NaN
#
#             5        6        7                8         9  ...        19  \
# 0        pace   growth   slowed           rising  mortgage  ...       NaN
# 0       homes  january  remains  cautiousbritain   largest  ...     sales
# 0     housing   lumber     data          suggest      home  ...       NaN
# 0       first     time    seven           months  december  ...  starting
# 0        hike     week     sign       conditions   housing  ...       NaN
# ..        ...      ...      ...              ...       ...  ...       ...
# 0   something     like    japan             days       NaN  ...       NaN
# 0       visit     york     city              NaN       NaN  ...       NaN
# 0        wall   street  weighed             odds  avoiding  ...       NaN
# 0        good     tips     make            build      rent  ...       NaN
# 0         NaN      NaN      NaN              NaN       NaN  ...       NaN
#
#            20   21   22   23   24   25   26   27           label
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0     january  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0   stabilize  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# ..        ...  ...  ...  ...  ...  ...  ...  ...             ...
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
# 0         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  housing_market
#
# [100 rows x 29 columns]

# %%
transactions = pd.concat([temp_1,temp_3])

# %%
transactions
# Out:
#            0       1           2             3         4          5        6  \
# 0       home  prices      nudged        higher  november       pace   growth
# 0       home  prices       going        across   country  aggregate  looking
# 0     google   fiber   launching          gbps  internet       plan    began
# 0   property  asking      prices          rose  february    weakest     gain
# 0      steps  change      unfair     landscape   include     ending    right
# ..       ...     ...         ...           ...       ...        ...      ...
# 0   proposes    turn  california        zoning    system  something     like
# 0      worst    seen       kwajo      tweneboa      said      visit     york
# 0      jamie   dimon      jeremy        siegel   experts       wall   street
# 0      build    rent    becoming  increasingly   popular       good     tips
# 0       none     NaN         NaN           NaN       NaN        NaN      NaN
#
#              7            8         9  ...            20    21            22  \
# 0       slowed       rising  mortgage  ...           NaN   NaN           NaN
# 0   individual      markets   however  ...           NaN   NaN           NaN
# 0      testing      october   service  ...         later  year          plan
# 0       record    rightmove   reports  ...        report  says        demand
# 0       taxing  residential  property  ...  civilisation  said  interlocutor
# ..         ...          ...       ...  ...           ...   ...           ...
# 0        japan         days       NaN  ...           NaN   NaN           NaN
# 0         city          NaN       NaN  ...           NaN   NaN           NaN
# 0      weighed         odds  avoiding  ...           NaN   NaN           NaN
# 0         make        build      rent  ...           NaN   NaN           NaN
# 0          NaN          NaN       NaN  ...           NaN   NaN           NaN
#
#            23      24           25    26   27   28           label
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_prices
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_prices
# 0   available   today       kansas  city  NaN  NaN  housing_prices
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_prices
# 0       right  social  catastrophe   NaN  NaN  NaN  housing_prices
# ..        ...     ...          ...   ...  ...  ...             ...
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_market
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_market
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_market
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_market
# 0         NaN     NaN          NaN   NaN  NaN  NaN  housing_market
#
# [200 rows x 30 columns]

# %%
transactions = transactions.iloc[: , :-1]

# %%
transactions.to_csv("transactions_data.csv", index = False, header = False)

# %%
test = pd.read_csv ("transactions_data.csv")
test.head()
# Out:
#        home   prices     nudged     higher  november       pace   growth  \
# 0      home   prices      going     across   country  aggregate  looking
# 1    google    fiber  launching       gbps  internet       plan    began
# 2  property   asking     prices       rose  february    weakest     gain
# 3     steps   change     unfair  landscape   include     ending    right
# 4   federal  reserve     policy      based     trust    central     bank
#
#        slowed       rising  mortgage  ... Unnamed: 19   Unnamed: 20  \
# 0  individual      markets   however  ...         NaN           NaN
# 1     testing      october   service  ...       areas         later
# 2      record    rightmove   reports  ...       start        report
# 3      taxing  residential  property  ...     british  civilisation
# 4     ability     maintain    stable  ...    attempts          cool
#
#   Unnamed: 21   Unnamed: 22 Unnamed: 23 Unnamed: 24  Unnamed: 25 Unnamed: 26  \
# 0         NaN           NaN         NaN         NaN          NaN         NaN
# 1        year          plan   available       today       kansas        city
# 2        says        demand         NaN         NaN          NaN         NaN
# 3        said  interlocutor       right      social  catastrophe         NaN
# 4     economy        prices       still      rising          NaN         NaN
#
#   Unnamed: 27 Unnamed: 28
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 29 columns]

# %%
#K-means clustering

# %%
#downloading data as csv to import csv in R for hierachical clustering
housing_prices.to_csv("housing_prices_test", index = False)

# %%
df = pd.read_csv ("housing_prices_test")
df
# Out:
#       index  MSSubClass MSZoning LotFrontage  LotArea Street Utilities  \
# 0         0          60       RL          65     8450   Pave    AllPub
# 1         1          20       RL          80     9600   Pave    AllPub
# 2         2          60       RL          68    11250   Pave    AllPub
# 3         3          70       RL          60     9550   Pave    AllPub
# 4         4          60       RL          84    14260   Pave    AllPub
# ...     ...         ...      ...         ...      ...    ...       ...
# 1422   1454          20       FV          62     7500   Pave    AllPub
# 1423   1455          60       RL          62     7917   Pave    AllPub
# 1424   1456          20       RL          85    13175   Pave    AllPub
# 1425   1458          20       RL          68     9717   Pave    AllPub
# 1426   1459          20       RL          75     9937   Pave    AllPub
#
#      Neighborhood BldgType  OverallCond  ...  BedroomAbvGr KitchenAbvGr  \
# 0         CollgCr     1Fam            5  ...             3            1
# 1         Veenker     1Fam            8  ...             3            1
# 2         CollgCr     1Fam            5  ...             3            1
# 3         Crawfor     1Fam            5  ...             3            1
# 4         NoRidge     1Fam            5  ...             4            1
# ...           ...      ...          ...  ...           ...          ...
# 1422      Somerst     1Fam            5  ...             2            1
# 1423      Gilbert     1Fam            5  ...             3            1
# 1424       NWAmes     1Fam            6  ...             3            1
# 1425        NAmes     1Fam            6  ...             2            1
# 1426      Edwards     1Fam            6  ...             3            1
#
#      Fireplaces GarageType GarageCars PoolQC     Fence MiscFeature  \
# 0             0     Attchd          2     NP  No Fence      Attchd
# 1             1     Attchd          2     NP  No Fence      Attchd
# 2             1     Attchd          2     NP  No Fence      Attchd
# 3             1     Detchd          3     NP  No Fence      Detchd
# 4             1     Attchd          3     NP  No Fence      Attchd
# ...         ...        ...        ...    ...       ...         ...
# 1422          0     Attchd          2     NP  No Fence      Attchd
# 1423          1     Attchd          2     NP  No Fence      Attchd
# 1424          2     Attchd          2     NP     MnPrv      Attchd
# 1425          0     Attchd          1     NP  No Fence      Attchd
# 1426          0     Attchd          1     NP  No Fence      Attchd
#
#       SaleCondition  SalePrice
# 0            Normal     208500
# 1            Normal     181500
# 2            Normal     223500
# 3           Abnorml     140000
# 4            Normal     250000
# ...             ...        ...
# 1422         Normal     185000
# 1423         Normal     175000
# 1424         Normal     210000
# 1425         Normal     142125
# 1426         Normal     147500
#
# [1427 rows x 29 columns]

# %%
numeric_cols = []
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        numeric_cols.append(col)

# %%
print('Numeric columns:', numeric_cols)
# Out:
# Numeric columns: ['index', 'MSSubClass', 'LotArea', 'OverallCond', 'YearBuilt', 'FullBath', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'SalePrice']

# %%
#Extracting only numerical data to perform K-means
numeric_housing_prices = housing_prices[['MSSubClass', 'LotArea', 'OverallCond', 'YearBuilt', 'FullBath', 'BedroomAbvGr', 
                                          'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'SalePrice']]

# %%
numeric_housing_prices.to_csv("numeric_housing_prices.csv", index = False)

# %%
df = pd.read_csv ("numeric_housing_prices.csv")
df
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  FullBath  BedroomAbvGr  \
# 0             60     8450            5       2003         2             3
# 1             20     9600            8       1976         2             3
# 2             60    11250            5       2001         2             3
# 3             70     9550            5       1915         1             3
# 4             60    14260            5       2000         2             4
# ...          ...      ...          ...        ...       ...           ...
# 1422          20     7500            5       2004         2             2
# 1423          60     7917            5       1999         2             3
# 1424          20    13175            6       1978         2             3
# 1425          20     9717            6       1950         1             2
# 1426          20     9937            6       1965         1             3
#
#       KitchenAbvGr  Fireplaces  GarageCars  SalePrice
# 0                1           0           2     208500
# 1                1           1           2     181500
# 2                1           1           2     223500
# 3                1           1           3     140000
# 4                1           1           3     250000
# ...            ...         ...         ...        ...
# 1422             1           0           2     185000
# 1423             1           1           2     175000
# 1424             1           2           2     210000
# 1425             1           0           1     142125
# 1426             1           0           1     147500
#
# [1427 rows x 10 columns]

# %%
#Scaling the data
from sklearn.preprocessing import StandardScaler 
numeric_housing_prices = StandardScaler().fit_transform(numeric_housing_prices)

# %%
#Elbow method to know the value the ideal value of K
from sklearn.preprocessing import StandardScaler 
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
import numpy as np

distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 10)
  
for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(numeric_housing_prices)
    kmeanModel.fit(numeric_housing_prices)
  
    distortions.append(sum(np.min(cdist(numeric_housing_prices, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / numeric_housing_prices.shape[0])
    inertias.append(kmeanModel.inertia_)
  
    mapping1[k] = sum(np.min(cdist(numeric_housing_prices, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / numeric_housing_prices.shape[0]
    mapping2[k] = kmeanModel.inertia_
# Out:
# C:\Users\rissh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\rissh\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(

# %%
for key, val in mapping1.items():
    print(f'{key} : {val}')
# Out:
# 1 : 2.87344729417012
# 2 : 2.435086197611591
# 3 : 2.2860631570562977
# 4 : 2.143382975209779
# 5 : 2.057994958899789
# 6 : 1.9731040074821264
# 7 : 1.9473709632394494
# 8 : 1.8734694229666573
# 9 : 1.8481188164446951

# %%
plt.figure(figsize=(7,5))
plt.plot(K, distortions, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Distortion')
plt.title('The Elbow Method using Distortion')
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA().fit(numeric_housing_prices)

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (7,5)

fig, ax = plt.subplots()
xi = np.arange(1, 11, step=1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 15, step=2)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
#PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components= 4)
principalComponents = pca.fit_transform(numeric_housing_prices)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3','principal component 4'])

# %%
#'MSSubClass', 'LotArea', 'OverallCond', 'YearBuilt', 'FullBath', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'SalePrice']

# %%
#K-Means Clustering based on K=2
plt.figure(figsize=(12,7))
kmeans = KMeans(n_clusters = 2)
label = kmeans.fit_predict(principalDf)
plt.scatter(housing_prices['YearBuilt'], housing_prices['SalePrice'], c = label, s= 50, cmap = 'viridis' )
plt.xlabel("YearBuilt") 
plt.ylabel("SalePrice") 
plt.title("K-Means Clustering based on K=2")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering based on K=2')

# %%
#K-Means Clustering based on K=3
plt.figure(figsize=(12,7))
kmeans = KMeans(n_clusters = 3)
label = kmeans.fit_predict(principalDf)
plt.scatter(housing_prices['YearBuilt'], housing_prices['SalePrice'], c = label, s= 50, cmap = 'viridis' )
plt.xlabel("YearBuilt") 
plt.ylabel("SalePrice") 
plt.title("K-Means Clustering based on K=3")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering based on K=3')

# %%
#K-Means Clustering based on K=4
plt.figure(figsize=(12,7))
kmeans = KMeans(n_clusters = 4)
label = kmeans.fit_predict(principalDf)
plt.scatter(housing_prices['YearBuilt'], housing_prices['SalePrice'], c = label, s= 50, cmap = 'viridis' )
plt.xlabel("YearBuilt") 
plt.ylabel("SalePrice") 
plt.title("K-Means Clustering based on K=4")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering based on K=4')

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(numeric_housing_prices)

# %%
kmeans_kwargs = {"init": "random", "n_init": 10, "max_iter": 300, "random_state": 42,}
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []
 # Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 11), silhouette_coefficients)
plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()
